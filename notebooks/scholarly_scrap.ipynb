# %% [markdown]
# # Libraries

# %%
# Google Scholar
# https://scholar.google.com/citations?user=sKSTKAoAAAAJ&hl=en
# https://scholar.google.com/citations?view_op=view_org&hl=en&org=1896398670060433590

import pickle
import numpy as np
import pandas as pd

from scholarly import scholarly
# https://github.com/scholarly-python-package/scholarly
# https://www.scraperapi.com/blog/best-google-scholar-apis-proxies/

from random import randint
from time import sleep

from collections import Counter
from itertools import combinations

# Scraper API
# https://www.scraperapi.com/blog/best-google-scholar-apis-proxies/
# https://dev.to/iankerins/build-your-own-google-scholar-api-with-python-scrapy-4p73

# %% [markdown]
# # Initial Scrapping

# %% [markdown]
# ### Load list of faculty

# %%
df_listFaculty = pd.read_csv('Data_FacultyAreas.csv')
df_listFaculty
# Out:
#         ID             Title                                        Area
# 0     1762       Amir Yacoby                             Applied Physics
# 1     2626       Ann Pearson         Environmental Science & Engineering
# 2     1795        Ariel Amir                         Applied Mathematics
# 3    13261   Ariel Procaccia                            Computer Science
# 4     1523  Barbara J. Grosz                            Computer Science
# ..     ...               ...                                         ...
# 120   1713      Yaron Singer                            Computer Science
# 121   1519       Yiling Chen                            Computer Science
# 122   1651            Yue Lu                      Electrical Engineering
# 123   1553       Zhigang Suo  Materials Science & Mechanical Engineering
# 124   1572     Zhiming Kuang         Environmental Science & Engineering
#
# [125 rows x 3 columns]

# %%
listFaculty = list(df_listFaculty['Title'])
listFaculty
# Out:
# ['Amir Yacoby',
#  'Ann Pearson',
#  'Ariel Amir',
#  'Ariel Procaccia',
#  'Barbara J. Grosz',
#  'Boaz Barak',
#  'Boris Kozinsky',
#  'Brian F. Farrell',
#  'Cengiz Pehlevan',
#  'Cherry Murray',
#  'Christin Y. Sander',
#  'Christopher Joseph Lombardo',
#  'Christopher Rycroft',
#  'Conor J Walsh',
#  'Cynthia Dwork',
#  'Cynthia Friend',
#  'Daniel J. Jacob',
#  'Daniel Needleman',
#  'Daniel P. Schrag',
#  'David A. Weitz',
#  'David Brooks',
#  'David C. Bell',
#  'David Clarke',
#  'David J. Malan',
#  'David Keith',
#  'David Mooney',
#  'David Parkes',
#  'David R. Nelson',
#  'Demba Ba',
#  'Doeke Romke Hekstra',
#  'Donald Elliot Ingber',
#  'Donhee Ham',
#  'Eddie Kohler',
#  'Efthimios Kaxiras',
#  'Elena Leah Glassman',
#  'Eli Tziperman',
#  'Elsie M Sunderland',
#  'Eric Mazur',
#  'Evelyn Hu',
#  'Federico Capasso',
#  'Finale Doshi-Velez',
#  'Flavio P. Calmon',
#  'Frank J. Doyle',
#  'Frank N Keutsch',
#  'Frans A. Spaepen',
#  'Gu-Yeon Wei',
#  'H.T. Kung',
#  'Hanspeter Pfister',
#  'Harry R. Lewis',
#  'James G. Anderson',
#  'James H. Waldo',
#  'James Mickens',
#  'James R. Rice',
#  'Jennifer Lewis',
#  'Jenny Hoffman',
#  'Jerry X. Mitrovica',
#  'Jia Liu',
#  'Joanna Aizenberg',
#  'John H. Shaw',
#  'John P. Holdren',
#  'Jonathan Zittrain',
#  'Joost J. Vlassak',
#  'Joze Bevk',
#  'Julia A. Mundy',
#  'Kaighin A McColl',
#  'Karen Brennan',
#  'Katia Bertoldi',
#  'Kit Parker',
#  'Krzysztof Z Gajos',
#  'L Mahadevan',
#  'Lene V. Hau',
#  'Leslie G. Valiant',
#  'Madhu Sudan',
#  'Margo S Levine',
#  'Marianna Katherine Linz',
#  'Marko Loncar',
#  'Markus Thomas Basan',
#  'Maurice Smith',
#  'Maxim Prigozhin',
#  'Michael B. McElroy',
#  'Michael D. Mitzenmacher',
#  'Michael D. Smith',
#  'Michael J. Aziz',
#  'Michael P. Brenner',
#  'Milind Tambe',
#  'Minlan Yu',
#  'Na Li',
#  'Nada Amin',
#  'Noel Michele Holbrook',
#  'Paul R Moorcroft',
#  'Pavlos Protopapas',
#  'Peter John Huybers',
#  'Philip Kim',
#  'Philippe Cluzel',
#  'Prineha Narang',
#  'Radhika Nagpal',
#  'Richard McCullough',
#  'Robert D. Howe',
#  'Robert J. Wood',
#  'Robert M. Westervelt',
#  'Robin Wordsworth',
#  'Roy G. Gordon',
#  'Salil P. Vadhan',
#  'Samir Mitragotri',
#  'Scot T. Martin',
#  'Sharad Ramanathan',
#  'Stephanie Gil',
#  'Stephen Chong',
#  'Steven C. Wofsy',
#  'Steven J. Gortler',
#  'Stratos Idreos',
#  'Stuart M. Shieber',
#  'Susan A Murphy',
#  'Tai T. Wu',
#  'Todd Zickler',
#  'Venkatesh Narayanamurti',
#  'Vijay Janapa Reddi',
#  'Vinothan N. Manoharan',
#  'Woodward Yang',
#  'Xin Li',
#  'Yaron Singer',
#  'Yiling Chen',
#  'Yue Lu',
#  'Zhigang Suo',
#  'Zhiming Kuang']

# %% [markdown]
# ### Keep only first and last names

# %%
def firstLastName(name):
    splitName = name.split()
    numName = len(splitName)
    
    firstName = splitName[0]
    lastName = splitName[numName-1]
    
    return firstName + ' ' + lastName

# %%
listFaculty_FirstLastName = [firstLastName(x) for x in listFaculty]
listFaculty_FirstLastName
# Out:
# ['Amir Yacoby',
#  'Ann Pearson',
#  'Ariel Amir',
#  'Ariel Procaccia',
#  'Barbara Grosz',
#  'Boaz Barak',
#  'Boris Kozinsky',
#  'Brian Farrell',
#  'Cengiz Pehlevan',
#  'Cherry Murray',
#  'Christin Sander',
#  'Christopher Lombardo',
#  'Christopher Rycroft',
#  'Conor Walsh',
#  'Cynthia Dwork',
#  'Cynthia Friend',
#  'Daniel Jacob',
#  'Daniel Needleman',
#  'Daniel Schrag',
#  'David Weitz',
#  'David Brooks',
#  'David Bell',
#  'David Clarke',
#  'David Malan',
#  'David Keith',
#  'David Mooney',
#  'David Parkes',
#  'David Nelson',
#  'Demba Ba',
#  'Doeke Hekstra',
#  'Donald Ingber',
#  'Donhee Ham',
#  'Eddie Kohler',
#  'Efthimios Kaxiras',
#  'Elena Glassman',
#  'Eli Tziperman',
#  'Elsie Sunderland',
#  'Eric Mazur',
#  'Evelyn Hu',
#  'Federico Capasso',
#  'Finale Doshi-Velez',
#  'Flavio Calmon',
#  'Frank Doyle',
#  'Frank Keutsch',
#  'Frans Spaepen',
#  'Gu-Yeon Wei',
#  'H.T. Kung',
#  'Hanspeter Pfister',
#  'Harry Lewis',
#  'James Anderson',
#  'James Waldo',
#  'James Mickens',
#  'James Rice',
#  'Jennifer Lewis',
#  'Jenny Hoffman',
#  'Jerry Mitrovica',
#  'Jia Liu',
#  'Joanna Aizenberg',
#  'John Shaw',
#  'John Holdren',
#  'Jonathan Zittrain',
#  'Joost Vlassak',
#  'Joze Bevk',
#  'Julia Mundy',
#  'Kaighin McColl',
#  'Karen Brennan',
#  'Katia Bertoldi',
#  'Kit Parker',
#  'Krzysztof Gajos',
#  'L Mahadevan',
#  'Lene Hau',
#  'Leslie Valiant',
#  'Madhu Sudan',
#  'Margo Levine',
#  'Marianna Linz',
#  'Marko Loncar',
#  'Markus Basan',
#  'Maurice Smith',
#  'Maxim Prigozhin',
#  'Michael McElroy',
#  'Michael Mitzenmacher',
#  'Michael Smith',
#  'Michael Aziz',
#  'Michael Brenner',
#  'Milind Tambe',
#  'Minlan Yu',
#  'Na Li',
#  'Nada Amin',
#  'Noel Holbrook',
#  'Paul Moorcroft',
#  'Pavlos Protopapas',
#  'Peter Huybers',
#  'Philip Kim',
#  'Philippe Cluzel',
#  'Prineha Narang',
#  'Radhika Nagpal',
#  'Richard McCullough',
#  'Robert Howe',
#  'Robert Wood',
#  'Robert Westervelt',
#  'Robin Wordsworth',
#  'Roy Gordon',
#  'Salil Vadhan',
#  'Samir Mitragotri',
#  'Scot Martin',
#  'Sharad Ramanathan',
#  'Stephanie Gil',
#  'Stephen Chong',
#  'Steven Wofsy',
#  'Steven Gortler',
#  'Stratos Idreos',
#  'Stuart Shieber',
#  'Susan Murphy',
#  'Tai Wu',
#  'Todd Zickler',
#  'Venkatesh Narayanamurti',
#  'Vijay Reddi',
#  'Vinothan Manoharan',
#  'Woodward Yang',
#  'Xin Li',
#  'Yaron Singer',
#  'Yiling Chen',
#  'Yue Lu',
#  'Zhigang Suo',
#  'Zhiming Kuang']

# %% [markdown]
# ### Scholarly test with single entries

# %%
search_query = scholarly.search_author('Amir Yacoby Harvard')
author = scholarly.fill(next(search_query))

# %%
author['scholar_id']
# Out:
# 'slFLfLYAAAAJ'

# %%
author
# Out:
# {'container_type': 'Author',
#  'filled': {'basics', 'coauthors', 'counts', 'indices', 'publications'},
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 2>,
#  'scholar_id': 'slFLfLYAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=slFLfLYAAAAJ',
#  'name': 'Amir Yacoby',
#  'affiliation': 'Professor of Physics, Harvard University',
#  'email_domain': '@g.harvard.edu',
#  'interests': ['Experimental Condensed Matter Physics'],
#  'citedby': 31269,
#  'coauthors': [],
#  'publications': [{'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Coherent manipulation of coupled electron spins in semiconductor quantum dots',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:u5HHmVD_uO8C',
#    'num_citations': 3465},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nanoscale magnetic sensing with an individual electronic spin in diamond',
#     'pub_year': '2008'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:d1gkVwhDpl0C',
#    'num_citations': 1789},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Observation of electron–hole puddles in graphene using a scanning single-electron transistor',
#     'pub_year': '2008'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:u-x6o8ySG0sC',
#    'num_citations': 1751},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'High-sensitivity diamond magnetometer with nanoscale resolution',
#     'pub_year': '2008'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:2osOgNQ5qMEC',
#    'num_citations': 1574},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Coherence and phase sensitive measurements in a quantum dot',
#     'pub_year': '1995'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:9yKSN-GCB0IC',
#    'num_citations': 854},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Dephasing time of GaAs electron-spin qubits coupled to a nuclear bath exceeding 200 μs',
#     'pub_year': '2011'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:zYLM7Y9cAGgC',
#    'num_citations': 647},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Triplet–singlet spin relaxation via nuclei in a double quantum dot',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:qjMakFHDy7sC',
#    'num_citations': 643},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'A robust scanning diamond sensor for nanoscale imaging with single nitrogen-vacancy centres',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:LkGwnXOMwfcC',
#    'num_citations': 581},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nonuniversal conductance quantization in quantum wires',
#     'pub_year': '1996'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:UeHWp8X0CEIC',
#    'num_citations': 581},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Demonstration of entanglement of electrostatically coupled singlet-triplet qubits',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:_FxGoFyzp5QC',
#    'num_citations': 564},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Optical magnetic imaging of living cells',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:5nxA0vEk-isC',
#    'num_citations': 532},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Measurement of the conductance of single conjugated molecules',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:IjCSPb-OGe4C',
#    'num_citations': 528},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Fault-tolerant architecture for quantum computation using electrically controlled semiconductor spins',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:Tyk-4Ss8FVUC',
#    'num_citations': 464},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Spin-charge separation and localization in one dimension',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:Y0pCki6q_DkC',
#    'num_citations': 456},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Universal quantum control of two-electron spin quantum bits using dynamic nuclear polarization',
#     'pub_year': '2009'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:eQOLeE2rZwMC',
#    'num_citations': 451},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Broken-symmetry states in doubly gated suspended bilayer graphene',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:ufrVoPGSRksC',
#    'num_citations': 426},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Relaxation, dephasing, and quantum control of electron spins in double quantum dots',
#     'pub_year': '2007'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:W7OEmFMy1HYC',
#    'num_citations': 412},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nanoscale magnetic imaging of a single electron spin under ambient conditions',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:UebtZRa9Y70C',
#    'num_citations': 386},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Broken-symmetry states and divergent resistance in suspended bilayer graphene',
#     'pub_year': '2009'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:WF5omc3nYNoC',
#    'num_citations': 379},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Tunneling spectroscopy of the elementary excitations in a one-dimensional wire',
#     'pub_year': '2002'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:YsMSGLbcyi4C',
#    'num_citations': 372},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Repetitive readout of a single electronic spin via quantum logic with nuclear spin ancillae',
#     'pub_year': '2009'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:Se3iqnhoufwC',
#    'num_citations': 344},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Charge noise spectroscopy using coherent exchange oscillations in a singlet-triplet qubit',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:_kc_bZDykSQC',
#    'num_citations': 330},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Induced superconductivity in the quantum spin Hall edge',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:dhFuZR0502QC',
#    'num_citations': 311},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Magnetic field imaging with nitrogen-vacancy ensembles',
#     'pub_year': '2011'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:Wp0gIr-vW9MC',
#    'num_citations': 304},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Enhancing the coherence of a spin qubit by operating it as a feedback loop that controls its nuclear spin bath',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:MXK_kJrjxJIC',
#    'num_citations': 273},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Coherence of nitrogen-vacancy electronic spin ensembles in diamond',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:L8Ckcad2t8MC',
#    'num_citations': 269},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Experimental evidence for resonant tunneling in a Luttinger liquid',
#     'pub_year': '2000'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:roLk4NBRz8UC',
#    'num_citations': 259},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Electron liquids and solids in one dimension',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:3fE2CSJIrl8C',
#    'num_citations': 250},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Subnanometre resolution in three-dimensional magnetic resonance imaging of individual dark spins',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:_Qo2XoVZTnwC',
#    'num_citations': 247},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nanoscale NMR spectroscopy and imaging of multiple nuclear species',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:hMod-77fHWUC',
#    'num_citations': 236},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'The microscopic nature of localization in the quantum Hall effect',
#     'pub_year': '2004'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:0EnyYjriUFMC',
#    'num_citations': 233},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Probing condensed matter physics with magnetometry based on nitrogen-vacancy centres in diamond',
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:a3BOlSfXSfwC',
#    'num_citations': 232},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Integrated diamond networks for quantum nanophotonics',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:qxL8FJ1GzNcC',
#    'num_citations': 229},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nuclear spin effects in semiconductor quantum dots',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:hFOr9nPyWt4C',
#    'num_citations': 219},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Suppression of spin-bath dynamics for improved coherence of multi-spin-qubit systems',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:mB3voiENLucC',
#    'num_citations': 217},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Interference and dephasing by electron-electron interaction on length scales shorter than the elastic mean free path',
#     'pub_year': '1991'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:hqOjcs7Dif8C',
#    'num_citations': 217},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Enhanced single-photon emission from a diamond–silver aperture',
#     'pub_year': '2011'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:mVmsd5A6BfQC',
#    'num_citations': 213},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Charge fractionalization in quantum wires',
#     'pub_year': '2008'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:ULOm3_A8WrAC',
#    'num_citations': 212},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Coherent optical transitions in implanted nitrogen vacancy centers',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:k_IJM867U9cC',
#    'num_citations': 201},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Phase rigidity and h/2e oscillations in a single-ring Aharonov-Bohm experiment',
#     'pub_year': '1996'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:8k81kl-MbHgC',
#    'num_citations': 192},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Electrical imaging of the quantum Hall state',
#     'pub_year': '1999'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:KlAtU1dfN6UC',
#    'num_citations': 180},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Suppressing qubit dephasing using real-time Hamiltonian estimation',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:isC4tDSrTZIC',
#    'num_citations': 179},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Unconventional sequence of fractional quantum Hall states in suspended graphene',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:7PzlFSSx8tAC',
#    'num_citations': 179},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Local compressibility measurements of correlated states in suspended bilayer graphene',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:M3ejUd6NZC8C',
#    'num_citations': 176},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Far-field optical imaging and manipulation of individual spins with nanoscale resolution',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:9ZlFYXVOiuMC',
#    'num_citations': 176},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nanoscale magnetometry with NV centers in diamond',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:O3NaXMp0MMsC',
#    'num_citations': 173},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Localization of fractionally charged quasi-particles',
#     'pub_year': '2004'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:aqlVkmm33-oC',
#    'num_citations': 170},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Dynamic nuclear polarization with single electron spins',
#     'pub_year': '2008'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:YOwf2qJgpHMC',
#    'num_citations': 164},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Theory of a single-atom point source for electrons',
#     'pub_year': '1989'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:Zph67rFs4hoC',
#    'num_citations': 161},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Unexpected Behavior of the Local Compressibility near the  Metal-Insulator Transition',
#     'pub_year': '2000'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:kNdYIx-mwKoC',
#    'num_citations': 159},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'High-fidelity entangling gate for double-quantum-dot spin qubits',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:VOx2b1Wkg3QC',
#    'num_citations': 158},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Gate-defined quantum confinement in suspended bilayer graphene',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:j3f4tGmQtD8C',
#    'num_citations': 158},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Control and local measurement of the spin chemical potential in a magnetic insulator',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:rmuvC79q63oC',
#    'num_citations': 156},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Self-aligned nanoscale SQUID on a tip',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:TQgYirikUcIC',
#    'num_citations': 155},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Superfluid spin transport through antiferromagnetic insulators',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:M05iB0D1s5AC',
#    'num_citations': 150},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Single-cell magnetic imaging using a quantum diamond microscope',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:u_35RYKgDlwC',
#    'num_citations': 149},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Quantum Hall effect, screening, and layer-polarized insulating states in twisted bilayer graphene',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:4JMBOYKVnBMC',
#    'num_citations': 149},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Quantum control of proximal spins using nanoscale magnetic resonance imaging',
#     'pub_year': '2011'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:qUcmZB5y_30C',
#    'num_citations': 147},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Topological superconductivity in a phase-controlled Josephson junction',
#     'pub_year': '2019'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:BJbdYPG6LGMC',
#    'num_citations': 144},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nanometre-scale probing of spin waves using single electron spins',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:4OULZ7Gr8RgC',
#    'num_citations': 139},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Quantization of the conductance of ballistic point contacts beyond the adiabatic approximation',
#     'pub_year': '1990'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:4TOpqqG69KYC',
#    'num_citations': 139},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Efficient photon detection from color centers in a diamond optical waveguide',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:NaGl4SEjCO4C',
#    'num_citations': 137},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Imaging of localized electronic states in the quantum Hall regime',
#     'pub_year': '2000'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:4DMP91E08xMC',
#    'num_citations': 134},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Microscopic structure of the metal-insulator transition in two dimensions',
#     'pub_year': '2001'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:QIV2ME_5wuYC',
#    'num_citations': 130},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Kramers pairs of majorana fermions and parafermions in fractional topological insulators',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:35N4QoGY0k4C',
#    'num_citations': 126},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Spatially resolved edge currents and guided-wave electronic states in graphene',
#     'pub_year': '2016'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:nb7KW1ujOQ8C',
#    'num_citations': 125},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Topological superconductivity in a planar Josephson junction',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:oNZyr7d5Mn4C',
#    'num_citations': 124},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Long-distance spin-spin coupling via floating gates',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:maZDTaKrznsC',
#    'num_citations': 124},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Local charge of the ν= 5/2 fractional quantum Hall state',
#     'pub_year': '2011'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:HDshCWvjkbEC',
#    'num_citations': 121},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Local thermometry of neutral modes on the quantum Hall edge',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:M3NEmzRMIkIC',
#    'num_citations': 118},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Enhanced solid-state multispin metrology using dynamical decoupling',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:blknAaTinKkC',
#    'num_citations': 118},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Inducing superconducting correlation in quantum Hall edge states',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:kz9GbA2Ns4gC',
#    'num_citations': 116},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Magnetostatic twists in room-temperature skyrmions explored by nitrogen-vacancy center spin texture reconstruction',
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:5icHVeHT4IsC',
#    'num_citations': 109},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Electron-hole asymmetric integer and fractional quantum Hall effect in bilayer graphene',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:RYcK_YlVTxYC',
#    'num_citations': 109},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Fractional quantum Hall phase transitions and four-flux states in graphene',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:BqipwSGYUEgC',
#    'num_citations': 108},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Magneto-transport spectroscopy on a quantum wire',
#     'pub_year': '1997'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:ZeXyd9-uunAC',
#    'num_citations': 108},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'NMR technique for determining the depth of shallow nitrogen-vacancy centers in diamond',
#     'pub_year': '2016'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:OU6Ihb5iCvQC',
#    'num_citations': 107},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Fourier magnetic imaging with nanoscale resolution and compressed sensing speed-up using electronic spins in diamond',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:xtRiw3GOFMkC',
#    'num_citations': 106},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Steady states of a microwave-irradiated quantum-Hall gas',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:-f6ydRqryjwC',
#    'num_citations': 105},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Coherent, mechanical control of a single electronic spin',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:YFjsv_pBGBYC',
#    'num_citations': 103},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Interacting electrons in one dimension beyond the Luttinger-liquid limit',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:iH-uZ7U-co4C',
#    'num_citations': 103},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Effect of exchange interaction on spin dephasing in a double quantum dot',
#     'pub_year': '2006'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:IWHjjKOFINEC',
#    'num_citations': 103},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Unexpected periodicity in an electronic double slit interference experiment',
#     'pub_year': '1994'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:R3hNpaxXUhUC',
#    'num_citations': 103},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Single-color centers implanted in diamond nanostructures',
#     'pub_year': '2011'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:GnPB-g6toBAC',
#    'num_citations': 98},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Electronic spin based enhancement of magnetometer sensitivity',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:5Ul4iDaHHb8C',
#    'num_citations': 96},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Pulsed-gate measurements of the singlet-triplet relaxation time in a two-electron double quantum dot',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:RHpTSmoSYBkC',
#    'num_citations': 96},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': '2D-1D coupling in cleaved edge overgrowth',
#     'pub_year': '2000'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:hC7cP41nSMkC',
#    'num_citations': 95},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Fabrication of nanoscale gaps in integrated circuits',
#     'pub_year': '2002'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:e5wmG9Sq2KIC',
#    'num_citations': 87},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Possible evidence for helical nuclear spin order in gaas quantum wires',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:2P1L_qKh6hAC',
#    'num_citations': 85},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'The nature of localization in graphene under quantum Hall conditions',
#     'pub_year': '2009'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:r0BpntZqJG4C',
#    'num_citations': 85},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Imaging viscous flow of the Dirac fluid in graphene',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:WHdLCjDvYFkC',
#    'num_citations': 81},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Strongly correlated Chern insulators in magic-angle twisted bilayer graphene',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:raTqNPD5sRQC',
#    'num_citations': 80},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Localization transition in a ballistic quantum wire',
#     'pub_year': '2006'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:JV2RwH3_ST0C',
#    'num_citations': 79},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Finite-size effects in tunneling between parallel quantum wires',
#     'pub_year': '2002'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:bEWYMUwI8FkC',
#    'num_citations': 77},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Anomalous conductance quantization in carbon nanotubes',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:J_g5lzvAfSwC',
#    'num_citations': 75},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Interference and zero-bias anomaly in tunneling between Luttinger-liquid wires',
#     'pub_year': '2003'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:NMxIlDl6LWMC',
#    'num_citations': 75},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Statistics of photon-subtracted and photon-added states',
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:GFxP56DSvIMC',
#    'num_citations': 74},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Quenching of dynamic nuclear polarization by spin–orbit coupling in GaAs quantum dots',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:_xSYboBqXhAC',
#    'num_citations': 70},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Fractional and integer quantum Hall effects in the zeroth Landau level in graphene',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:lSLTfruPkqcC',
#    'num_citations': 70},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Solid-state circuit for spin entanglement generation and purification',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:TFP_iSt0sucC',
#    'num_citations': 69},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Graphene rests easy', 'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:3s1wT3WcHBgC',
#    'num_citations': 68},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Studies on electric triggering of the metal-insulator transition in VO2 thin films between 77 K and 300 K',
#     'pub_year': '2011'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:HoB7MX3m0LUC',
#    'num_citations': 64},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Controlled finite momentum pairing and spatially varying order parameter in proximitized HgTe quantum wells',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:sSrBHYA8nusC',
#    'num_citations': 63},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Detecting Majorana modes in one-dimensional wires by charge sensing',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:bFI3QPDXJZMC',
#    'num_citations': 63},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Atomically precise, custom-design origami graphene nanostructures',
#     'pub_year': '2019'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:kzcSZmkxUKAC',
#    'num_citations': 62},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Synthetic diamond materials for quantum and optical applications and methods of making the same',
#     'pub_year': '2016'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:eq2jaN3J8jMC',
#    'num_citations': 59},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Relaxation and readout visibility of a singlet-triplet qubit in an Overhauser field gradient',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:70eg2SAEIzsC',
#    'num_citations': 59},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Dynamic nuclear polarization in double quantum dots',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:ns9cj8rnVeAC',
#    'num_citations': 58},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Tri and tri again', 'pub_year': '2011'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:ZHo1McVdvXMC',
#    'num_citations': 57},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Charge and spin addition energies of a one-dimensional quantum dot',
#     'pub_year': '2000'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:RGFaLdJalmkC',
#    'num_citations': 55},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Revealing topological superconductivity in extended quantum spin Hall Josephson junctions',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:fPk4N6BV_jEC',
#    'num_citations': 54},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Charge fractionalization in nonchiral Luttinger systems',
#     'pub_year': '2008'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:g5m5HwL7SMYC',
#    'num_citations': 53},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Mach-Zehnder interferometry using spin-and valley-polarized quantum Hall edge states in graphene',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:4fGpz3EwCPoC',
#    'num_citations': 48},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Semiclassical model for the dephasing of a two-electron spin qubit coupled to a coherently evolving nuclear spin bath',
#     'pub_year': '2011'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:rO6llkc54NcC',
#    'num_citations': 48},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Code properties from holographic geometries',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:umqufdRvDiIC',
#    'num_citations': 46},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Transport and optics in quantum wires fabricated by MBE overgrowth on the (110) cleaved edge',
#     'pub_year': '1997'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:vV6vV6tmYwMC',
#    'num_citations': 42},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Decoherence imaging of spin ensembles using a scanning single-electron spin in diamond',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:NhqRSupF_l8C',
#    'num_citations': 40},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Spin Superfluidity in the  Quantum Hall State of Graphene',
#     'pub_year': '2016'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:p__nRnzSRKYC',
#    'num_citations': 38},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Microscopic manifestation of the spin phase transition at filling factor 2/3',
#     'pub_year': '2007'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:zA6iFVUQeVQC',
#    'num_citations': 36},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Dephasing of ballistic electrons as a function of temperature and carrier density',
#     'pub_year': '1994'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:ldfaerwXgEUC',
#    'num_citations': 36},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Scanning diamond NV center probes compatible with conventional AFM technology',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:sNmaIFBj_lkC',
#    'num_citations': 35},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Physical model of the genotype-to-phenotype map of proteins',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:QYdC8u9Cj1oC',
#    'num_citations': 34},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Tuning methods for semiconductor spin qubits',
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:Ehil0879vHcC',
#    'num_citations': 33},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Electrical generation and detection of spin waves in a quantum Hall ferromagnet',
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:ZzlSgRqYykMC',
#    'num_citations': 31},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Coupling two spin qubits with a high-impedance resonator',
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:LhH-TYMQEocC',
#    'num_citations': 29},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Local spin susceptibilities of low-dimensional electron systems',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:f2IySw72cVMC',
#    'num_citations': 29},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Method and system for magnetic resonance imaging using nitrogen-vacancy centers',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:dBIO0h50nwkC',
#    'num_citations': 28},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'High-efficiency resonant amplification of weak magnetic fields for single spin magnetometry at room temperature',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:p2g8aNsByqUC',
#    'num_citations': 28},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Current-induced anisotropy and reordering of the electron liquid-crystal phases in a two-dimensional electron system',
#     'pub_year': '2007'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:cFHS6HbyZ2cC',
#    'num_citations': 28},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nanoparticles and nanogaps: controlled positioning and fabrication',
#     'pub_year': '2003'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:dfsIfKJdRG4C',
#    'num_citations': 27},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Information-geometric approach to the renormalization group',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:9c2xU6iGI7YC',
#    'num_citations': 26},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Crystallographic orientation dependent reactive ion etching in single crystal diamond',
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:_OXeSy2IsFwC',
#    'num_citations': 25},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nanoscale detection of magnon excitations with variable wavevectors through a quantum spin sensor',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:prdVHNxh-e8C',
#    'num_citations': 23},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Long mean free path of hot electrons selectively injected to higher subbands',
#     'pub_year': '1990'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:pyW8ca7W8N0C',
#    'num_citations': 21},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Tuning topological superconductivity in phase-controlled Josephson junctions with Rashba and Dresselhaus spin-orbit coupling',
#     'pub_year': '2019'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:MhiOAD_qIWkC',
#    'num_citations': 20},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Readout of singlet-triplet qubits at large magnetic field gradients',
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:u-coK7KVo8oC',
#    'num_citations': 20},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Detecting Non-Abelian anyons by charging spectroscopy',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:l7t_Zn2s7bgC',
#    'num_citations': 20},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Charge and spin manipulation in a few-electron double dot',
#     'pub_year': '2006'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:P5F9QuxV20EC',
#    'num_citations': 20},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Proposal for the detection of magnetic monopoles in spin ice via nanoscale magnetometry',
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:ODE9OILHJdcC',
#    'num_citations': 19},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Observation of electron coherence and Fabry–Perot standing waves at a graphene edge',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:yFnVuubrUp4C',
#    'num_citations': 19},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Gate-defined wires in HgTe quantum wells: From Majorana fermions to spintronics',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:abG-DnoFyZgC',
#    'num_citations': 19},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Domain patterns in the microwave-induced zero-resistance state',
#     'pub_year': '2006'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:CHSYGLWDkRkC',
#    'num_citations': 19},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Adiabatic mode selection and the accuracy of the quantization of the conductance of ballistic point contacts',
#     'pub_year': '1990'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:EUQCXRtRnyEC',
#    'num_citations': 18},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'High-energy quasiparticle injection into mesoscopic superconductors',
#     'pub_year': '2021'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:kF1pexMAQbMC',
#    'num_citations': 17},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Long coherence of electron spins coupled to a nuclear spin bath',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:SeFeTyx0c_EC',
#    'num_citations': 17},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'A robust, scanning quantum system for nanoscale sensing and imaging',
#     'pub_year': '2011'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:dshw04ExmUIC',
#    'num_citations': 16},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Microscopy with a single electron transistor probe',
#     'pub_year': '1998'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:a0OBvERweLwC',
#    'num_citations': 16},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Inhomogeneous nuclear spin flips: Feedback mechanism between electronic states in a double quantum dot and the underlying nuclear spin bath',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:b0M2c_1WBrUC',
#    'num_citations': 15},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Topological charge pumping in twisted bilayer graphene',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:5bg8sr1QxYwC',
#    'num_citations': 14},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Magnetic field sensor device for direct magnetic field imaging and method of fabrication thereof',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:BrmTIyaxlBUC',
#    'num_citations': 14},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Local compressibility measurement of the ν t o t= 1 quantum Hall state in a bilayer electron system',
#     'pub_year': '2013'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:WbkHhVStYXYC',
#    'num_citations': 14},
#   {'container_type': 'Publication',
# ...
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Spin Reconstruction in Quantum Hall Strips',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:nrtMV_XWKgEC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Transport in dually-gated suspended bilayer graphene devices in electric and magnetic fields',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:VLnqNzywnoUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Scanning magnetometry of nanomagnets via a nitrogen-vacancy center in diamond scanning microscope',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:WqliGbK-hY8C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Raman spectroscopy of suspended mono and bilayer graphene',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:PELIpwtuRlgC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Effect of magnetic field alignment on the electron spin decoherence in NV diamond',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:J-pR_7NvFogC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Electron-electron interactions in bilayer graphene.',
#     'pub_year': '2009'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:WC23djZS0W4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Preparation of Non-equilibrium Nuclear Spin States in Quantum Dots',
#     'pub_year': '2009'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:N5tVd3kTz84C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Preparation of Nuclear Spin States in Double Quantum Dots',
#     'pub_year': '2009'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:FPJr55Dyh1AC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Zamboni force in pumping of angular momentum from electron to nuclear spins via the Overhauser effect',
#     'pub_year': '2009'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:ipzZ9siozwsC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Emergence of spin structure in quantum wires under strong magnetic fields',
#     'pub_year': '2009'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:9Nmd_mFXekcC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'First announcement', 'pub_year': '2009'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:PYBJJbyH-FwC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nanoscale magnetic sensing using spin qubits in diamond',
#     'pub_year': '2009'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:PkcyUWeTMh0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nanoscale magnetometry with nitogen-vacancy color centers in diamond',
#     'pub_year': '2008'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:S16KYo8Pm5AC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Measurement of the Conductance of Single Conjugated Molecules',
#     'pub_year': '2007'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:5qfkUJPXOUwC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'General Physics: Statistical and Quantum Mechanics, Quantum Information, etc.-Noninvariance of Space-and Time-Scale Ranges under a Lorentz Transformation and the Implications …',
#     'pub_year': '2007'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:4vMrXwiscB8C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Semiconductors II: Surfaces, interfaces, microstructures, and related topics-Relaxation, dephasing, and quantum control of electron spins in double quantum dots',
#     'pub_year': '2007'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:g3aElNc5_aQC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nanoscale vector force sensing using nitrogen-vacancy centres in diamond',
#     'pub_year': '2007'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:AvfA0Oy_GE0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Semiconductor-based quantum computing: from physical gates to architectures',
#     'pub_year': '2006'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:MLfJN-KU85MC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Control and manipulation of single electron spins in GaAs Quantum Dots',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:EYYDruWGBe4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Chargeand spin manipulationin a few-electrondouble dot',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:WAzi4Gm8nLoC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Nanoelectronics for quantum information processing',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:eMMeJKvmdy0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Numerical studies of domain patterns in inhomogeneous microwave-irradiated quantum Hall gas',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:L7CI7m0gUJcC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Electron spin relaxation by hyperfine interaction in a double quantum dot',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:kzcrU_BdoSEC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Steady States of the Inhomogenous Microwave Irradiated Quantum Hall Gas',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:_B80troHkn4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Measurement of the local potential in the stripes and bubble phase',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:tkaPQYYpVKoC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Localization of Fractionally Charged Quasi-Particles',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:WA5NYHcadZ8C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'RAPID COMMUNICATIONS-Semiconductors II-Surfaces, interfaces, microstructures, and related topics-Pulsed-gate measurements of the singlet-triplet relaxation time in a two …',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:e_rmSamDkqQC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Spin-charge separation in quantum wires',
#     'pub_year': '2005'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:JQOojiI6XY0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Spin-Charge Separation and Localization in One-Dimension Measured Using Momentum Resolved Tunneling',
#     'pub_year': '2003'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:LI9QrySNdTsC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Electrical Transport Through Single Molecules',
#     'pub_year': '2003'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:hkOj_22Ku90C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Experimental Study of Tunneling in 1D',
#     'pub_year': '2001'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:Z5m8FVwuT1cC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Tunneling Between Two Parallel Wires',
#     'pub_year': '2001'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:XD-gHx7UXLsC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'The Microscopic Structure of the Two-Dimensional Metal-Insulator Transition',
#     'pub_year': '2001'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:HE397vMXCloC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Contacting a wire on the edge', 'pub_year': '2000'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:hMsQuOkrut0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Imaging the Local Electrostatic Potential of a Two Dimensional Electron Gas in the Quantum Hall Regime',
#     'pub_year': '1998'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:VL0QpB8kHFEC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Large Deviations from Universal Conductance Quantization in Quantum Wires.',
#     'pub_year': '1997'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:WZBGuue-350C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Coherence and phase sensitive measurements with a quantum dot',
#     'pub_year': '1996'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:olpn-zPbct0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Transport Spectroscopy of a Quantum Wire',
#     'pub_year': '1996'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:gsN89kCJA0AC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Observations on Conductance Quantization and Dephasing in Mesoscale Systems',
#     'pub_year': '1996'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:5awf1xo2G04C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'INTERFERENCE AND DEPHASING BY ELECTRON-ELECTRON INTERACTION IN BALLISTIC CONDUCTORS',
#     'pub_year': '1992'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:OcBU2YAGkTUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Temperature Dependence of the Resonant Tunneling Process',
#     'pub_year': '1991'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:dQ2og3OwTAUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Raman Scattering From a Single Molecule between Two Metal Nanoparticles',
#     'pub_year': '1990'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:fFSKOagxvKUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Supporting Information for A Magnon Scattering Platform'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:IsPWOBWtZBwC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Measurement of Spin-Charge Separation and Spontaneous Localization in One-Dimensional Wires'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:1DsIQWDZLl8C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Electrometry using coherent exchange oscillations in a singlet-triplet qubit'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:nRpfm8aw39MC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Exploring Magnonic Excitation in Quantum Hall Ferromagnets'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:gKiMpY-AVTkC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'CLUSTER 3: Imaging Electrons at the Nanoscale'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:OR75R8vi5nAC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Conference picture vi Preface 1 vii'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:uc_IGeMz5qoC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': '1. Photonics and novel light emitters'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:fEOibwPWpKIC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Invited Papers'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:_Re3VWB3Y0AC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 2>,
#    'bib': {'title': 'Unconventional Fractional Quantum Hall Sequence in Graphene'},
#    'filled': False,
#    'author_pub_id': 'slFLfLYAAAAJ:1yQoGdGgb4wC',
#    'num_citations': 0}],
#  'cites_per_year': {1996: 80,
#   1997: 96,
#   1998: 111,
#   1999: 110,
#   2000: 182,
#   2001: 222,
#   2002: 274,
#   2003: 264,
#   2004: 279,
#   2005: 338,
#   2006: 653,
#   2007: 751,
#   2008: 945,
#   2009: 997,
#   2010: 1174,
#   2011: 1402,
#   2012: 1760,
#   2013: 2094,
#   2014: 2217,
#   2015: 2299,
#   2016: 2347,
#   2017: 2587,
#   2018: 2523,
#   2019: 2469,
#   2020: 2494,
#   2021: 2222},
#  'citedby5y': 14650,
#  'hindex': 87,
#  'hindex5y': 66,
#  'i10index': 163,
#  'i10index5y': 140}

# %%
fake_query = scholarly.search_author('Fake Author Harvard')
fake_author = scholarly.fill(next(fake_query))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /var/folders/jy/3fpggxm12w52p1spnxd3fxh80000gn/T/ipykernel_6827/137735510.py in <module>
#       1 fake_query = scholarly.search_author('Fake Author Harvard')
# ----> 2 fake_author = scholarly.fill(next(fake_query))
#
# StopIteration:

# %%
fake_query
# Out:
# <generator object Navigator.search_authors at 0x120e3ec10>

# %%
try:
    fake_query = scholarly.search_author('Fake Author Harvard')
    fake_author = scholarly.fill(next(fake_query))
except:
    print("NO AUTHOR")
# Out:
# NO AUTHOR

# %% [markdown]
# ### Scholarly run with faculty list

# %%
def get_id(list_titles):
    list_ids = []
    list_containers = []
    
    for title in list_titles:
        sleep(randint(5,30))
        
        try:
            query = scholarly.search_author(title+' Harvard')
            author = scholarly.fill(next(query))
            author_id = author['scholar_id']
            
            print(title)
            list_ids.append(author_id)
            list_containers.append(author)
        except:
            print("NO PROFILE: "+title)
            list_ids.append('None')
            list_containers.append('None')
            
    return list_ids, list_containers

# %%
list1, list2 = get_id(listFaculty_FirstLastName)
# Out:
# Amir Yacoby
# Ann Pearson
# NO PROFILE: Ariel Amir
# Ariel Procaccia
# NO PROFILE: Barbara Grosz
# Boaz Barak
# Boris Kozinsky
# Brian Farrell
# Cengiz Pehlevan
# NO PROFILE: Cherry Murray
# Christin Sander
# NO PROFILE: Christopher Lombardo
# Christopher Rycroft
# Conor Walsh
# Cynthia Dwork
# Cynthia Friend
# Daniel Jacob
# NO PROFILE: Daniel Needleman
# Daniel Schrag
# David Weitz
# David Brooks
# David Bell
# David Clarke
# NO PROFILE: David Malan
# David Keith
# David Mooney
# David Parkes
# David Nelson
# Demba Ba
# Doeke Hekstra
# Donald Ingber
# NO PROFILE: Donhee Ham
# Eddie Kohler
# Efthimios Kaxiras
# Elena Glassman
# Eli Tziperman
# Elsie Sunderland
# Eric Mazur
# NO PROFILE: Evelyn Hu
# Federico Capasso
# Finale Doshi-Velez
# Flavio Calmon
# NO PROFILE: Frank Doyle
# NO PROFILE: Frank Keutsch
# NO PROFILE: Frans Spaepen
# Gu-Yeon Wei
# H.T. Kung
# Hanspeter Pfister
# NO PROFILE: Harry Lewis
# NO PROFILE: James Anderson
# James Waldo
# James Mickens
# James Rice
# Jennifer Lewis
# Jenny Hoffman
# Jerry Mitrovica
# Jia Liu
# Joanna Aizenberg
# John Shaw
# NO PROFILE: John Holdren
# Jonathan Zittrain
# Joost Vlassak
# NO PROFILE: Joze Bevk
# Julia Mundy
# Kaighin McColl
# Karen Brennan
# Katia Bertoldi
# Kit Parker
# Krzysztof Gajos
# L Mahadevan
# NO PROFILE: Lene Hau
# NO PROFILE: Leslie Valiant
# Madhu Sudan
# NO PROFILE: Margo Levine
# Marianna Linz
# Marko Loncar
# Markus Basan
# Maurice Smith
# Maxim Prigozhin
# NO PROFILE: Michael McElroy
# Michael Mitzenmacher
# Michael Smith
# Michael Aziz
# Michael Brenner
# Milind Tambe
# Minlan Yu
# Na Li
# Nada Amin
# NO PROFILE: Noel Holbrook
# NO PROFILE: Paul Moorcroft
# Pavlos Protopapas
# Peter Huybers
# Philip Kim
# Philippe Cluzel
# Prineha Narang
# Radhika Nagpal
# Richard McCullough
# NO PROFILE: Robert Howe
# Robert Wood
# Robert Westervelt
# Robin Wordsworth
# NO PROFILE: Roy Gordon
# Salil Vadhan
# Samir Mitragotri
# Scot Martin
# NO PROFILE: Sharad Ramanathan
# Stephanie Gil
# Stephen Chong
# Steven Wofsy
# Steven Gortler
# Stratos Idreos
# Stuart Shieber
# Susan Murphy
# NO PROFILE: Tai Wu
# Todd Zickler
# Venkatesh Narayanamurti
# Vijay Reddi
# Vinothan Manoharan
# NO PROFILE: Woodward Yang
# Xin Li
# Yaron Singer
# Yiling Chen
# Yue Lu
# Zhigang Suo
# NO PROFILE: Zhiming Kuang

# %% [markdown]
# ### Append lists to df

# %%
df_listFaculty['Scholar ID'] = list1
df_listFaculty
# Out:
#         ID             Title                                        Area  \
# 0     1762       Amir Yacoby                             Applied Physics
# 1     2626       Ann Pearson         Environmental Science & Engineering
# 2     1795        Ariel Amir                         Applied Mathematics
# 3    13261   Ariel Procaccia                            Computer Science
# 4     1523  Barbara J. Grosz                            Computer Science
# ..     ...               ...                                         ...
# 120   1713      Yaron Singer                            Computer Science
# 121   1519       Yiling Chen                            Computer Science
# 122   1651            Yue Lu                      Electrical Engineering
# 123   1553       Zhigang Suo  Materials Science & Mechanical Engineering
# 124   1572     Zhiming Kuang         Environmental Science & Engineering
#
#        Scholar ID
# 0    slFLfLYAAAAJ
# 1    Hwk4sP0AAAAJ
# 2            None
# 3    8ZpV-lkAAAAJ
# 4            None
# ..            ...
# 120  j-MBXNMAAAAJ
# 121  x_7xA0UAAAAJ
# 122  84FUioAAAAAJ
# 123  GlBl-VUAAAAJ
# 124          None
#
# [125 rows x 4 columns]

# %% [markdown]
# ### Export data

# %%
df_listFaculty.to_csv('df_listFaculty.csv', index=False)

# %%
readCSV_listFaculty = pd.read_csv('df_listFaculty.csv')
readCSV_listFaculty
# Out:
#         ID             Title                                        Area  \
# 0     1762       Amir Yacoby                             Applied Physics
# 1     2626       Ann Pearson         Environmental Science & Engineering
# 2     1795        Ariel Amir                         Applied Mathematics
# 3    13261   Ariel Procaccia                            Computer Science
# 4     1523  Barbara J. Grosz                            Computer Science
# ..     ...               ...                                         ...
# 120   1713      Yaron Singer                            Computer Science
# 121   1519       Yiling Chen                            Computer Science
# 122   1651            Yue Lu                      Electrical Engineering
# 123   1553       Zhigang Suo  Materials Science & Mechanical Engineering
# 124   1572     Zhiming Kuang         Environmental Science & Engineering
#
#        Scholar ID
# 0    slFLfLYAAAAJ
# 1    Hwk4sP0AAAAJ
# 2            None
# 3    8ZpV-lkAAAAJ
# 4            None
# ..            ...
# 120  j-MBXNMAAAAJ
# 121  x_7xA0UAAAAJ
# 122  84FUioAAAAAJ
# 123  GlBl-VUAAAAJ
# 124          None
#
# [125 rows x 4 columns]

# %%
with open('output_scholarly.pkl', 'wb') as output:
    pickle.dump(list2, output, pickle.HIGHEST_PROTOCOL)
