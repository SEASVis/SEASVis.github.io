# %% [markdown]
# # Libraries

# %%
# Google Scholar
# https://scholar.google.com/citations?user=sKSTKAoAAAAJ&hl=en
# https://scholar.google.com/citations?view_op=view_org&hl=en&org=1896398670060433590

import pickle
import numpy as np
import pandas as pd

from scholarly import scholarly
# https://github.com/scholarly-python-package/scholarly
# https://www.scraperapi.com/blog/best-google-scholar-apis-proxies/
from scholarly import ProxyGenerator

from random import randint
from time import sleep

from collections import Counter
from itertools import combinations

import json

# %% [markdown]
# # Import Datasets

# %%
df_listFaculty = pd.read_csv('df_listFaculty.csv')
df_listFaculty
# Out:
#         ID             Title                                        Area  \
# 0     1762       Amir Yacoby                             Applied Physics
# 1     2626       Ann Pearson         Environmental Science & Engineering
# 2     1795        Ariel Amir                         Applied Mathematics
# 3    13261   Ariel Procaccia                            Computer Science
# 4     1523  Barbara J. Grosz                            Computer Science
# ..     ...               ...                                         ...
# 120   1713      Yaron Singer                            Computer Science
# 121   1519       Yiling Chen                            Computer Science
# 122   1651            Yue Lu                      Electrical Engineering
# 123   1553       Zhigang Suo  Materials Science & Mechanical Engineering
# 124   1572     Zhiming Kuang         Environmental Science & Engineering
#
#        Scholar ID
# 0    slFLfLYAAAAJ
# 1    Hwk4sP0AAAAJ
# 2            None
# 3    8ZpV-lkAAAAJ
# 4            None
# ..            ...
# 120  j-MBXNMAAAAJ
# 121  x_7xA0UAAAAJ
# 122  84FUioAAAAAJ
# 123  GlBl-VUAAAAJ
# 124          None
#
# [125 rows x 4 columns]

# %%
with open('output_scholarly.pkl', 'rb') as input:
    list_scholarly = pickle.load(input)

# %% [markdown]
# # Generate Collaboration Data

# %% [markdown]
# ### Create dictionary map between faculty name and Google Scholar ID

# %%
map_facultyID = dict(zip(df_listFaculty['Scholar ID'], df_listFaculty['Title']))
map_facultyID
# Out:
# {'slFLfLYAAAAJ': 'Amir Yacoby',
#  'Hwk4sP0AAAAJ': 'Ann Pearson',
#  'None': 'Zhiming Kuang',
#  '8ZpV-lkAAAAJ': 'Ariel Procaccia',
#  'I0fbJ6cAAAAJ': 'Boaz Barak',
#  '9I4ltOIAAAAJ': 'Boris Kozinsky',
#  'fABXPQQAAAAJ': 'Brian F. Farrell',
#  'veDLTPEAAAAJ': 'Cengiz Pehlevan',
#  '-XVcP5QAAAAJ': 'Christin Y. Sander',
#  'IS_xUuIAAAAJ': 'Christopher Rycroft',
#  'sKSTKAoAAAAJ': 'Conor J Walsh',
#  'pxeyQ_QAAAAJ': 'Cynthia Dwork',
#  'qmEw4LoAAAAJ': 'Cynthia Friend',
#  '5C1bJKkAAAAJ': 'Daniel J. Jacob',
#  'fKQ4QLYAAAAJ': 'Daniel P. Schrag',
#  'R1cfTCoAAAAJ': 'David A. Weitz',
#  'vXHA_XYAAAAJ': 'David Brooks',
#  'tCCmmgQAAAAJ': 'David C. Bell',
#  'wC0M5uoAAAAJ': 'David Clarke',
#  'PfciJkgAAAAJ': 'David Keith',
#  'ZflJqeUAAAAJ': 'David Mooney',
#  'JUn8PgwAAAAJ': 'David Parkes',
#  'jGboazkAAAAJ': 'David R. Nelson',
#  'qHiACEgAAAAJ': 'Demba Ba',
#  'UEgdNEoAAAAJ': 'Doeke Romke Hekstra',
#  '3hzhsK4AAAAJ': 'Donald Elliot Ingber',
#  'VMihW8oAAAAJ': 'Eddie Kohler',
#  's9cO1fUAAAAJ': 'Efthimios Kaxiras',
#  'C_r8d0AAAAAJ': 'Elena Leah Glassman',
#  'yu8-BNUAAAAJ': 'Eli Tziperman',
#  'FLbkR3MAAAAJ': 'Elsie M Sunderland',
#  '6-rjB04AAAAJ': 'Eric Mazur',
#  'CmpEzW8AAAAJ': 'Federico Capasso',
#  'hwQtFB0AAAAJ': 'Finale Doshi-Velez',
#  'P8N_YH4AAAAJ': 'Flavio P. Calmon',
#  'IR0yJB8AAAAJ': 'Gu-Yeon Wei',
#  'iLQqwosAAAAJ': 'H.T. Kung',
#  'VWX-GMAAAAAJ': 'Hanspeter Pfister',
#  'e5rEazQAAAAJ': 'James H. Waldo',
#  '7m5-SfEAAAAJ': 'James Mickens',
#  'Qh3ws80AAAAJ': 'James R. Rice',
#  'Wdny3bkAAAAJ': 'Jennifer Lewis',
#  'a8Ki3L0AAAAJ': 'Jenny Hoffman',
#  'pfodAvkAAAAJ': 'Jerry X. Mitrovica',
#  'VzehWeYAAAAJ': 'Jia Liu',
#  'xKJyuMAAAAAJ': 'Joanna Aizenberg',
#  'ghCaa6sAAAAJ': 'John H. Shaw',
#  'aWZ0YN4AAAAJ': 'Jonathan Zittrain',
#  'sXPp5nEAAAAJ': 'Joost J. Vlassak',
#  'J3EwZi0AAAAJ': 'Julia A. Mundy',
#  'wFyikJgAAAAJ': 'Kaighin A McColl',
#  'DifL8OoAAAAJ': 'Karen Brennan',
#  'Jt1sCk8AAAAJ': 'Katia Bertoldi',
#  'Ut0YbEoAAAAJ': 'Kit Parker',
#  'MnnERiQAAAAJ': 'Krzysztof Z Gajos',
#  'iiyj5MsAAAAJ': 'L Mahadevan',
#  'D-RwB3YAAAAJ': 'Madhu Sudan',
#  'LZmkSvMAAAAJ': 'Marianna Katherine Linz',
#  'HSDt9D0AAAAJ': 'Marko Loncar',
#  'yjfGWV8AAAAJ': 'Markus Thomas Basan',
#  'lDsOeZIAAAAJ': 'Maurice Smith',
#  'e9jAOccAAAAJ': 'Maxim Prigozhin',
#  'e8aRmAsAAAAJ': 'Michael D. Mitzenmacher',
#  'BiiIlnQAAAAJ': 'Michael D. Smith',
#  '1KYlUH0AAAAJ': 'Michael J. Aziz',
#  'X6sP4F8AAAAJ': 'Michael P. Brenner',
#  'YOVZiJkAAAAJ': 'Milind Tambe',
#  'C_QXDzoAAAAJ': 'Minlan Yu',
#  'qdGelXoAAAAJ': 'Na Li',
#  '9cGEmcgAAAAJ': 'Nada Amin',
#  'hlFnwxwAAAAJ': 'Pavlos Protopapas',
#  'CO3EcrgAAAAJ': 'Peter John Huybers',
#  'vKodLNwAAAAJ': 'Philip Kim',
#  '1DpUSnsAAAAJ': 'Philippe Cluzel',
#  'yGmN1GEAAAAJ': 'Prineha Narang',
#  'a3ZGDsoAAAAJ': 'Radhika Nagpal',
#  'CyXmgzIAAAAJ': 'Richard McCullough',
#  'FTYtHb4AAAAJ': 'Robert J. Wood',
#  'RnzsQOEAAAAJ': 'Robert M. Westervelt',
#  'jo2FHKcAAAAJ': 'Robin Wordsworth',
#  'dqVjyRQAAAAJ': 'Salil P. Vadhan',
#  '3_77zesAAAAJ': 'Samir Mitragotri',
#  'PCtoyLcAAAAJ': 'Scot T. Martin',
#  'F_kiAZwAAAAJ': 'Stephanie Gil',
#  '5bxyMBwAAAAJ': 'Stephen Chong',
#  'ZRdM_M8AAAAJ': 'Steven C. Wofsy',
#  '66qppJsAAAAJ': 'Steven J. Gortler',
#  'rg6Bl5YAAAAJ': 'Stratos Idreos',
#  'oq8WAwsAAAAJ': 'Stuart M. Shieber',
#  'q-DPFdUAAAAJ': 'Susan A Murphy',
#  'oizZKrsAAAAJ': 'Todd Zickler',
#  'odZy3ygAAAAJ': 'Venkatesh Narayanamurti',
#  'gy4UVGcAAAAJ': 'Vijay Janapa Reddi',
#  'XwrePIwAAAAJ': 'Vinothan N. Manoharan',
#  'j_E4jDcAAAAJ': 'Xin Li',
#  'j-MBXNMAAAAJ': 'Yaron Singer',
#  'x_7xA0UAAAAJ': 'Yiling Chen',
#  '84FUioAAAAAJ': 'Yue Lu',
#  'GlBl-VUAAAAJ': 'Zhigang Suo'}

# %% [markdown]
# ### Create faculty links based on shared publications

# %%
dict_pubs = {}

for i in range(len(list_scholarly)):
    if list_scholarly[i] != 'None':
        author = map_facultyID[list_scholarly[i]['scholar_id']]
        list_pubs = list_scholarly[i]['publications']
        num_pubs = len(list_pubs)
        
        for i in range(num_pubs):
            pub_title = list_pubs[i]['bib']['title']
            
            if pub_title in dict_pubs and author not in dict_pubs[pub_title]:
                dict_pubs[pub_title].append(author)
            else:
                dict_pubs[pub_title] = [author]

# %%
dict_pubs_filter1 = {key:value for key,value in dict_pubs.items() if len(value) > 1}
print(len(dict_pubs_filter1))
print(list(dict_pubs_filter1.items())[:20])
# Out:
# 1141
# [('A robust scanning diamond sensor for nanoscale imaging with single nitrogen-vacancy centres', ['Amir Yacoby', 'Marko Loncar']), ('Integrated diamond networks for quantum nanophotonics', ['Amir Yacoby', 'Marko Loncar']), ('Enhanced single-photon emission from a diamond–silver aperture', ['Amir Yacoby', 'Marko Loncar']), ('Coherent optical transitions in implanted nitrogen vacancy centers', ['Amir Yacoby', 'Marko Loncar']), ('Inducing superconducting correlation in quantum Hall edge states', ['Amir Yacoby', 'Philip Kim']), ('Single-color centers implanted in diamond nanostructures', ['Amir Yacoby', 'Marko Loncar']), ('Imaging viscous flow of the Dirac fluid in graphene', ['Amir Yacoby', 'Philip Kim']), ('Atomically precise, custom-design origami graphene nanostructures', ['Amir Yacoby', 'Philip Kim']), ('Synthetic diamond materials for quantum and optical applications and methods of making the same', ['Amir Yacoby', 'Marko Loncar']), ('A robust, scanning quantum system for nanoscale sensing and imaging', ['Amir Yacoby', 'Marko Loncar']), ('Imaging phonon-mediated hydrodynamic flow in WTe2 with cryogenic quantum magnetometry', ['Amir Yacoby', 'Prineha Narang']), ('Data-driven studies of magnetic two-dimensional materials', ['Amir Yacoby', 'Efthimios Kaxiras']), ('Magnetic field fingerprinting of integrated-circuit activity with a quantum diamond microscope', ['Amir Yacoby', 'Marko Loncar']), ('Model wave functions for interfaces between lattice Laughlin states', ['Amir Yacoby', 'Philip Kim']), ('Aharonov–Bohm effect in graphene-based Fabry–Pérot quantum Hall interferometers', ['Amir Yacoby', 'Philip Kim']), ('Logarithmic singularities and quantum oscillations in magnetically doped topological insulators', ['Amir Yacoby', 'Philip Kim']), ('Induced superconductivity in the fractional quantum Hall edge', ['Amir Yacoby', 'Philip Kim']), ('On-chip single crystal diamond resonators', ['Amir Yacoby', 'Marko Loncar']), ('One-dimensional moiré superlattices and flat bands in collapsed chiral carbon nanotubes', ['Amir Yacoby', 'Efthimios Kaxiras', 'Philip Kim']), ('Spectroscopic signatures of time-reversal symmetry breaking superconductivity', ['Amir Yacoby', 'Prineha Narang'])]

# %%
authors_2 = Counter()

for authors in list(dict_pubs_filter1.values()):
    authors.sort()
    for comb in combinations(authors, 2):
        authors_2[comb] += 1

authors_2.most_common()[:20]
# Out:
# [(('David Brooks', 'Gu-Yeon Wei'), 153),
#  (('Daniel J. Jacob', 'Steven C. Wofsy'), 60),
#  (('Federico Capasso', 'Marko Loncar'), 55),
#  (('Conor J Walsh', 'Robert J. Wood'), 50),
#  (('Joost J. Vlassak', 'Zhigang Suo'), 46),
#  (('Cynthia Friend', 'Efthimios Kaxiras'), 44),
#  (('Eric Mazur', 'Marko Loncar'), 30),
#  (('Daniel J. Jacob', 'Elsie M Sunderland'), 28),
#  (('David Brooks', 'Vijay Janapa Reddi'), 24),
#  (('Donald Elliot Ingber', 'Kit Parker'), 23),
#  (('Jerry X. Mitrovica', 'Peter John Huybers'), 23),
#  (('Gu-Yeon Wei', 'Vijay Janapa Reddi'), 21),
#  (('Amir Yacoby', 'Philip Kim'), 19),
#  (('Radhika Nagpal', 'Robert J. Wood'), 19),
#  (('David Mooney', 'Donald Elliot Ingber'), 19),
#  (('Conor J Walsh', 'David Mooney'), 18),
#  (('Joanna Aizenberg', 'Marko Loncar'), 16),
#  (('Gu-Yeon Wei', 'Robert J. Wood'), 14),
#  (('David Clarke', 'Robert J. Wood'), 14),
#  (('Joanna Aizenberg', 'Katia Bertoldi'), 14)]

# %%
links = []
for pair in authors_2.most_common():
    author1 = pair[0][0]
    author2 = pair[0][1]
    count = pair[1]
    links.append({
        "source": author1,
        "target": author2,
        "value": count
    })
    
links
# Out:
# [{'source': 'David Brooks', 'target': 'Gu-Yeon Wei', 'value': 153},
#  {'source': 'Daniel J. Jacob', 'target': 'Steven C. Wofsy', 'value': 60},
#  {'source': 'Federico Capasso', 'target': 'Marko Loncar', 'value': 55},
#  {'source': 'Conor J Walsh', 'target': 'Robert J. Wood', 'value': 50},
#  {'source': 'Joost J. Vlassak', 'target': 'Zhigang Suo', 'value': 46},
#  {'source': 'Cynthia Friend', 'target': 'Efthimios Kaxiras', 'value': 44},
#  {'source': 'Eric Mazur', 'target': 'Marko Loncar', 'value': 30},
#  {'source': 'Daniel J. Jacob', 'target': 'Elsie M Sunderland', 'value': 28},
#  {'source': 'David Brooks', 'target': 'Vijay Janapa Reddi', 'value': 24},
#  {'source': 'Donald Elliot Ingber', 'target': 'Kit Parker', 'value': 23},
#  {'source': 'Jerry X. Mitrovica', 'target': 'Peter John Huybers', 'value': 23},
#  {'source': 'Gu-Yeon Wei', 'target': 'Vijay Janapa Reddi', 'value': 21},
#  {'source': 'Amir Yacoby', 'target': 'Philip Kim', 'value': 19},
#  {'source': 'Radhika Nagpal', 'target': 'Robert J. Wood', 'value': 19},
#  {'source': 'David Mooney', 'target': 'Donald Elliot Ingber', 'value': 19},
#  {'source': 'Conor J Walsh', 'target': 'David Mooney', 'value': 18},
#  {'source': 'Joanna Aizenberg', 'target': 'Marko Loncar', 'value': 16},
#  {'source': 'Gu-Yeon Wei', 'target': 'Robert J. Wood', 'value': 14},
#  {'source': 'David Clarke', 'target': 'Robert J. Wood', 'value': 14},
#  {'source': 'Joanna Aizenberg', 'target': 'Katia Bertoldi', 'value': 14},
#  {'source': 'Steven J. Gortler', 'target': 'Todd Zickler', 'value': 14},
#  {'source': 'Amir Yacoby', 'target': 'Marko Loncar', 'value': 13},
#  {'source': 'Conor J Walsh', 'target': 'Katia Bertoldi', 'value': 13},
#  {'source': 'Cynthia Friend', 'target': 'Joanna Aizenberg', 'value': 13},
#  {'source': 'David A. Weitz', 'target': 'L Mahadevan', 'value': 13},
#  {'source': 'David Clarke', 'target': 'Zhigang Suo', 'value': 13},
#  {'source': 'Eric Mazur', 'target': 'Michael J. Aziz', 'value': 13},
#  {'source': 'David A. Weitz', 'target': 'David Mooney', 'value': 12},
#  {'source': 'David Clarke', 'target': 'Katia Bertoldi', 'value': 12},
#  {'source': 'Federico Capasso', 'target': 'Philip Kim', 'value': 12},
#  {'source': 'Efthimios Kaxiras', 'target': 'Philip Kim', 'value': 11},
#  {'source': 'David Brooks', 'target': 'Michael D. Smith', 'value': 10},
#  {'source': 'Gu-Yeon Wei', 'target': 'Michael D. Smith', 'value': 10},
#  {'source': 'Michael D. Smith', 'target': 'Vijay Janapa Reddi', 'value': 10},
#  {'source': 'Philip Kim', 'target': 'Robert M. Westervelt', 'value': 10},
#  {'source': 'Hanspeter Pfister', 'target': 'Krzysztof Z Gajos', 'value': 10},
#  {'source': 'Madhu Sudan', 'target': 'Salil P. Vadhan', 'value': 10},
#  {'source': 'David Parkes', 'target': 'Yiling Chen', 'value': 9},
#  {'source': 'Daniel P. Schrag', 'target': 'Michael J. Aziz', 'value': 9},
#  {'source': 'Federico Capasso',
#   'target': 'Venkatesh Narayanamurti',
#   'value': 9},
#  {'source': 'Daniel P. Schrag', 'target': 'Eli Tziperman', 'value': 8},
#  {'source': 'Donald Elliot Ingber', 'target': 'Eric Mazur', 'value': 8},
#  {'source': 'Donald Elliot Ingber', 'target': 'Joanna Aizenberg', 'value': 8},
#  {'source': 'Efthimios Kaxiras', 'target': 'Joost J. Vlassak', 'value': 8},
#  {'source': 'Joanna Aizenberg', 'target': 'L Mahadevan', 'value': 8},
#  {'source': 'Ariel Procaccia', 'target': 'David Parkes', 'value': 7},
#  {'source': 'David A. Weitz', 'target': 'Donald Elliot Ingber', 'value': 7},
#  {'source': 'David Mooney', 'target': 'Zhigang Suo', 'value': 7},
#  {'source': 'Efthimios Kaxiras', 'target': 'Robert M. Westervelt', 'value': 7},
#  {'source': 'Michael J. Aziz',
#   'target': 'Venkatesh Narayanamurti',
#   'value': 7},
#  {'source': 'Amir Yacoby', 'target': 'Efthimios Kaxiras', 'value': 6},
#  {'source': 'Cynthia Friend', 'target': 'Eric Mazur', 'value': 6},
#  {'source': 'David A. Weitz', 'target': 'David R. Nelson', 'value': 6},
#  {'source': 'Federico Capasso', 'target': 'Michael J. Aziz', 'value': 6},
#  {'source': 'Ariel Procaccia', 'target': 'Yiling Chen', 'value': 5},
#  {'source': 'Daniel J. Jacob', 'target': 'Scot T. Martin', 'value': 5},
#  {'source': 'Kit Parker', 'target': 'L Mahadevan', 'value': 5},
#  {'source': 'David Brooks', 'target': 'Robert J. Wood', 'value': 5},
#  {'source': 'David Clarke', 'target': 'Federico Capasso', 'value': 5},
#  {'source': 'Katia Bertoldi', 'target': 'Zhigang Suo', 'value': 5},
#  {'source': 'Efthimios Kaxiras', 'target': 'Michael J. Aziz', 'value': 5},
#  {'source': 'Federico Capasso', 'target': 'Vinothan N. Manoharan', 'value': 5},
#  {'source': 'Federico Capasso', 'target': 'Joanna Aizenberg', 'value': 5},
#  {'source': 'Joanna Aizenberg', 'target': 'Zhigang Suo', 'value': 5},
#  {'source': 'David Parkes', 'target': 'Krzysztof Z Gajos', 'value': 4},
#  {'source': 'Ariel Procaccia', 'target': 'Milind Tambe', 'value': 4},
#  {'source': 'Katia Bertoldi', 'target': 'Robert J. Wood', 'value': 4},
#  {'source': 'Daniel P. Schrag', 'target': 'David Keith', 'value': 4},
#  {'source': 'David A. Weitz', 'target': 'Kit Parker', 'value': 4},
#  {'source': 'David A. Weitz', 'target': 'Vinothan N. Manoharan', 'value': 4},
#  {'source': 'David Mooney', 'target': 'Joost J. Vlassak', 'value': 4},
#  {'source': 'Efthimios Kaxiras', 'target': 'Zhigang Suo', 'value': 4},
#  {'source': 'Efthimios Kaxiras', 'target': 'Hanspeter Pfister', 'value': 4},
#  {'source': 'Eric Mazur', 'target': 'Salil P. Vadhan', 'value': 4},
#  {'source': 'Jennifer Lewis', 'target': 'Robert J. Wood', 'value': 4},
#  {'source': 'Jennifer Lewis', 'target': 'Katia Bertoldi', 'value': 4},
#  {'source': 'Amir Yacoby', 'target': 'Prineha Narang', 'value': 3},
#  {'source': 'Boaz Barak', 'target': 'Salil P. Vadhan', 'value': 3},
#  {'source': 'Jia Liu', 'target': 'Zhigang Suo', 'value': 3},
#  {'source': 'Christopher Rycroft', 'target': 'L Mahadevan', 'value': 3},
#  {'source': 'Cynthia Friend', 'target': 'Scot T. Martin', 'value': 3},
#  {'source': 'David A. Weitz', 'target': 'Robert M. Westervelt', 'value': 3},
#  {'source': 'David Brooks', 'target': 'Michael D. Mitzenmacher', 'value': 3},
#  {'source': 'Gu-Yeon Wei', 'target': 'Michael D. Mitzenmacher', 'value': 3},
#  {'source': 'David Clarke', 'target': 'Jennifer Lewis', 'value': 3},
#  {'source': 'David Clarke', 'target': 'Radhika Nagpal', 'value': 3},
#  {'source': 'David Parkes', 'target': 'Michael D. Mitzenmacher', 'value': 3},
#  {'source': 'Donald Elliot Ingber',
#   'target': 'Robert M. Westervelt',
#   'value': 3},
#  {'source': 'Donald Elliot Ingber', 'target': 'Radhika Nagpal', 'value': 3},
#  {'source': 'Federico Capasso', 'target': 'Todd Zickler', 'value': 3},
#  {'source': 'Finale Doshi-Velez', 'target': 'Susan A Murphy', 'value': 3},
#  {'source': 'Jennifer Lewis', 'target': 'Joanna Aizenberg', 'value': 3},
#  {'source': 'Joost J. Vlassak', 'target': 'Kit Parker', 'value': 3},
#  {'source': 'Krzysztof Z Gajos', 'target': 'Stuart M. Shieber', 'value': 3},
#  {'source': 'Marko Loncar', 'target': 'Robert M. Westervelt', 'value': 3},
#  {'source': 'Michael D. Mitzenmacher',
#   'target': 'Salil P. Vadhan',
#   'value': 3},
#  {'source': 'Ann Pearson', 'target': 'Daniel P. Schrag', 'value': 2},
#  {'source': 'Ann Pearson', 'target': 'Peter John Huybers', 'value': 2},
#  {'source': 'Boris Kozinsky', 'target': 'Cynthia Friend', 'value': 2},
#  {'source': 'Conor J Walsh', 'target': 'Jennifer Lewis', 'value': 2},
#  {'source': 'David Mooney', 'target': 'Katia Bertoldi', 'value': 2},
#  {'source': 'Conor J Walsh', 'target': 'Radhika Nagpal', 'value': 2},
#  {'source': 'Joost J. Vlassak', 'target': 'Robert J. Wood', 'value': 2},
#  {'source': 'Daniel J. Jacob', 'target': 'Daniel P. Schrag', 'value': 2},
#  {'source': 'Eli Tziperman', 'target': 'Steven C. Wofsy', 'value': 2},
#  {'source': 'Daniel P. Schrag', 'target': 'Jerry X. Mitrovica', 'value': 2},
#  {'source': 'Donald Elliot Ingber', 'target': 'L Mahadevan', 'value': 2},
#  {'source': 'David A. Weitz', 'target': 'Joanna Aizenberg', 'value': 2},
#  {'source': 'David A. Weitz', 'target': 'Zhigang Suo', 'value': 2},
#  {'source': 'David A. Weitz', 'target': 'Michael J. Aziz', 'value': 2},
#  {'source': 'David Mooney', 'target': 'Eric Mazur', 'value': 2},
#  {'source': 'David Parkes', 'target': 'Milind Tambe', 'value': 2},
#  {'source': 'David R. Nelson', 'target': 'Joanna Aizenberg', 'value': 2},
#  {'source': 'Efthimios Kaxiras', 'target': 'Jenny Hoffman', 'value': 2},
#  {'source': 'Efthimios Kaxiras', 'target': 'Pavlos Protopapas', 'value': 2},
#  {'source': 'Eli Tziperman', 'target': 'Peter John Huybers', 'value': 2},
#  {'source': 'Eli Tziperman', 'target': 'Marianna Katherine Linz', 'value': 2},
#  {'source': 'Marko Loncar', 'target': 'Michael J. Aziz', 'value': 2},
#  {'source': 'Finale Doshi-Velez', 'target': 'Krzysztof Z Gajos', 'value': 2},
#  {'source': 'Finale Doshi-Velez', 'target': 'Milind Tambe', 'value': 2},
#  {'source': 'H.T. Kung', 'target': 'Michael D. Smith', 'value': 2},
#  {'source': 'Hanspeter Pfister', 'target': 'Todd Zickler', 'value': 2},
#  {'source': 'Hanspeter Pfister',
#   'target': 'Michael D. Mitzenmacher',
#   'value': 2},
#  {'source': 'Jennifer Lewis', 'target': 'L Mahadevan', 'value': 2},
#  {'source': 'Jennifer Lewis', 'target': 'Joost J. Vlassak', 'value': 2},
#  {'source': 'Joanna Aizenberg', 'target': 'Joost J. Vlassak', 'value': 2},
#  {'source': 'Joost J. Vlassak', 'target': 'Michael J. Aziz', 'value': 2},
#  {'source': 'Kit Parker', 'target': 'Robert J. Wood', 'value': 2},
#  {'source': 'Katia Bertoldi', 'target': 'Kit Parker', 'value': 2},
#  {'source': 'Marko Loncar', 'target': 'Philip Kim', 'value': 2},
#  {'source': 'Michael D. Mitzenmacher', 'target': 'Minlan Yu', 'value': 2},
#  {'source': 'Salil P. Vadhan', 'target': 'Yiling Chen', 'value': 2},
#  {'source': 'Amir Yacoby', 'target': 'Federico Capasso', 'value': 1},
#  {'source': 'Efthimios Kaxiras', 'target': 'Federico Capasso', 'value': 1},
#  {'source': 'Amir Yacoby', 'target': 'Robert M. Westervelt', 'value': 1},
#  {'source': 'Ariel Procaccia', 'target': 'Krzysztof Z Gajos', 'value': 1},
#  {'source': 'Krzysztof Z Gajos', 'target': 'Yiling Chen', 'value': 1},
#  {'source': 'Ariel Procaccia', 'target': 'Finale Doshi-Velez', 'value': 1},
#  {'source': 'Boaz Barak', 'target': 'Michael D. Mitzenmacher', 'value': 1},
#  {'source': 'Boris Kozinsky', 'target': 'Jia Liu', 'value': 1},
#  {'source': 'Boris Kozinsky', 'target': 'Zhigang Suo', 'value': 1},
#  {'source': 'Boris Kozinsky', 'target': 'Efthimios Kaxiras', 'value': 1},
#  {'source': 'Cengiz Pehlevan', 'target': 'L Mahadevan', 'value': 1},
#  {'source': 'Christopher Rycroft', 'target': 'Katia Bertoldi', 'value': 1},
#  {'source': 'Conor J Walsh', 'target': 'David A. Weitz', 'value': 1},
#  {'source': 'Conor J Walsh', 'target': 'Zhigang Suo', 'value': 1},
#  {'source': 'Conor J Walsh', 'target': 'Joost J. Vlassak', 'value': 1},
#  {'source': 'Conor J Walsh', 'target': 'Finale Doshi-Velez', 'value': 1},
#  {'source': 'Finale Doshi-Velez', 'target': 'Robert J. Wood', 'value': 1},
#  {'source': 'Conor J Walsh', 'target': 'Krzysztof Z Gajos', 'value': 1},
#  {'source': 'Robert J. Wood', 'target': 'Todd Zickler', 'value': 1},
#  {'source': 'Conor J Walsh', 'target': 'Maurice Smith', 'value': 1},
#  {'source': 'Cynthia Dwork', 'target': 'Salil P. Vadhan', 'value': 1},
#  {'source': 'Cynthia Friend', 'target': 'Joost J. Vlassak', 'value': 1},
#  {'source': 'Joost J. Vlassak', 'target': 'Scot T. Martin', 'value': 1},
#  {'source': 'Efthimios Kaxiras', 'target': 'Joanna Aizenberg', 'value': 1},
#  {'source': 'Cynthia Friend', 'target': 'Michael J. Aziz', 'value': 1},
#  {'source': 'Daniel J. Jacob', 'target': 'David Keith', 'value': 1},
#  {'source': 'Daniel J. Jacob', 'target': 'Eli Tziperman', 'value': 1},
#  {'source': 'Daniel P. Schrag', 'target': 'Steven C. Wofsy', 'value': 1},
#  {'source': 'David A. Weitz', 'target': 'Jennifer Lewis', 'value': 1},
#  {'source': 'David A. Weitz', 'target': 'Jerry X. Mitrovica', 'value': 1},
#  {'source': 'David A. Weitz', 'target': 'Katia Bertoldi', 'value': 1},
#  {'source': 'David A. Weitz', 'target': 'Steven C. Wofsy', 'value': 1},
#  {'source': 'David A. Weitz', 'target': 'Federico Capasso', 'value': 1},
#  {'source': 'Michael D. Mitzenmacher',
#   'target': 'Vijay Janapa Reddi',
#   'value': 1},
#  {'source': 'David Clarke', 'target': 'Kit Parker', 'value': 1},
#  {'source': 'Kit Parker', 'target': 'Zhigang Suo', 'value': 1},
#  {'source': 'David Mooney', 'target': 'Michael P. Brenner', 'value': 1},
#  {'source': 'David Mooney', 'target': 'Joanna Aizenberg', 'value': 1},
#  {'source': 'David Mooney', 'target': 'L Mahadevan', 'value': 1},
#  {'source': 'David Mooney', 'target': 'Samir Mitragotri', 'value': 1},
#  {'source': 'David Parkes', 'target': 'Stuart M. Shieber', 'value': 1},
#  {'source': 'David Parkes', 'target': 'Salil P. Vadhan', 'value': 1},
#  {'source': 'David Parkes', 'target': 'Yaron Singer', 'value': 1},
#  {'source': 'David Parkes', 'target': 'Finale Doshi-Velez', 'value': 1},
#  {'source': 'Philip Kim', 'target': 'Radhika Nagpal', 'value': 1},
#  {'source': 'David R. Nelson', 'target': 'Vinothan N. Manoharan', 'value': 1},
#  {'source': 'David R. Nelson', 'target': 'Joost J. Vlassak', 'value': 1},
#  {'source': 'Demba Ba', 'target': 'Donald Elliot Ingber', 'value': 1},
#  {'source': 'Demba Ba', 'target': 'Steven C. Wofsy', 'value': 1},
#  {'source': 'Donald Elliot Ingber', 'target': 'Steven C. Wofsy', 'value': 1},
#  {'source': 'Donald Elliot Ingber', 'target': 'Katia Bertoldi', 'value': 1},
#  {'source': 'Donald Elliot Ingber', 'target': 'Samir Mitragotri', 'value': 1},
#  {'source': 'Eddie Kohler', 'target': 'James Mickens', 'value': 1},
#  {'source': 'Efthimios Kaxiras', 'target': 'Prineha Narang', 'value': 1},
#  {'source': 'Efthimios Kaxiras', 'target': 'Eric Mazur', 'value': 1},
#  {'source': 'Elena Leah Glassman', 'target': 'Stephen Chong', 'value': 1},
#  {'source': 'Elena Leah Glassman', 'target': 'Finale Doshi-Velez', 'value': 1},
#  {'source': 'Elsie M Sunderland', 'target': 'Steven C. Wofsy', 'value': 1},
#  {'source': 'Eric Mazur', 'target': 'Joanna Aizenberg', 'value': 1},
#  {'source': 'Eric Mazur', 'target': 'Todd Zickler', 'value': 1},
#  {'source': 'Federico Capasso', 'target': 'Jennifer Lewis', 'value': 1},
#  {'source': 'Federico Capasso', 'target': 'Kit Parker', 'value': 1},
#  {'source': 'Finale Doshi-Velez', 'target': 'James H. Waldo', 'value': 1},
#  {'source': 'Finale Doshi-Velez', 'target': 'Pavlos Protopapas', 'value': 1},
#  {'source': 'Gu-Yeon Wei', 'target': 'Radhika Nagpal', 'value': 1},
#  {'source': 'H.T. Kung', 'target': 'Radhika Nagpal', 'value': 1},
#  {'source': 'H.T. Kung', 'target': 'Robert J. Wood', 'value': 1},
#  {'source': 'H.T. Kung', 'target': 'Stuart M. Shieber', 'value': 1},
#  {'source': 'Michael D. Smith', 'target': 'Stuart M. Shieber', 'value': 1},
#  {'source': 'Hanspeter Pfister', 'target': 'Stuart M. Shieber', 'value': 1},
#  {'source': 'Hanspeter Pfister', 'target': 'Radhika Nagpal', 'value': 1},
#  {'source': 'Krzysztof Z Gajos', 'target': 'Radhika Nagpal', 'value': 1},
#  {'source': 'James Mickens', 'target': 'Stephanie Gil', 'value': 1},
#  {'source': 'James R. Rice', 'target': 'Zhigang Suo', 'value': 1},
#  {'source': 'Jennifer Lewis', 'target': 'Kit Parker', 'value': 1},
#  {'source': 'Jennifer Lewis', 'target': 'Michael J. Aziz', 'value': 1},
#  {'source': 'Joanna Aizenberg', 'target': 'Michael J. Aziz', 'value': 1},
#  {'source': 'Joanna Aizenberg', 'target': 'Vinothan N. Manoharan', 'value': 1},
#  {'source': 'Joost J. Vlassak', 'target': 'L Mahadevan', 'value': 1},
#  {'source': 'Kaighin A McColl', 'target': 'Peter John Huybers', 'value': 1},
#  {'source': 'L Mahadevan', 'target': 'Robert J. Wood', 'value': 1},
#  {'source': 'L Mahadevan', 'target': 'Vinothan N. Manoharan', 'value': 1},
#  {'source': 'Madhu Sudan', 'target': 'Michael D. Mitzenmacher', 'value': 1},
#  {'source': 'Marianna Katherine Linz',
#   'target': 'Steven C. Wofsy',
#   'value': 1},
#  {'source': 'Marko Loncar', 'target': 'Prineha Narang', 'value': 1},
#  {'source': 'Marko Loncar', 'target': 'Venkatesh Narayanamurti', 'value': 1},
#  {'source': 'Michael D. Mitzenmacher', 'target': 'Milind Tambe', 'value': 1},
#  {'source': 'Michael D. Mitzenmacher', 'target': 'Yaron Singer', 'value': 1},
#  {'source': 'Milind Tambe', 'target': 'Yaron Singer', 'value': 1},
#  {'source': 'Milind Tambe', 'target': 'Minlan Yu', 'value': 1},
#  {'source': 'Peter John Huybers', 'target': 'Steven C. Wofsy', 'value': 1},
#  {'source': 'Salil P. Vadhan', 'target': 'Stephen Chong', 'value': 1},
#  {'source': 'Stephen Chong', 'target': 'Yiling Chen', 'value': 1}]

# %% [markdown]
# # Create faculty nodes with name and academic area

# %%
df_listFaculty
# Out:
#         ID             Title                                        Area  \
# 0     1762       Amir Yacoby                             Applied Physics
# 1     2626       Ann Pearson         Environmental Science & Engineering
# 2     1795        Ariel Amir                         Applied Mathematics
# 3    13261   Ariel Procaccia                            Computer Science
# 4     1523  Barbara J. Grosz                            Computer Science
# ..     ...               ...                                         ...
# 120   1713      Yaron Singer                            Computer Science
# 121   1519       Yiling Chen                            Computer Science
# 122   1651            Yue Lu                      Electrical Engineering
# 123   1553       Zhigang Suo  Materials Science & Mechanical Engineering
# 124   1572     Zhiming Kuang         Environmental Science & Engineering
#
#        Scholar ID
# 0    slFLfLYAAAAJ
# 1    Hwk4sP0AAAAJ
# 2            None
# 3    8ZpV-lkAAAAJ
# 4            None
# ..            ...
# 120  j-MBXNMAAAAJ
# 121  x_7xA0UAAAAJ
# 122  84FUioAAAAAJ
# 123  GlBl-VUAAAAJ
# 124          None
#
# [125 rows x 4 columns]

# %%
areaNumbers = {
    "Applied Mathematics": 0,
    "Applied Physics": 1,
    "Bioengineering": 2,
    "Computer Science": 3,
    "Electrical Engineering": 4,
    "Environmental Science & Engineering": 5,
    "Materials Science & Mechanical Engineering": 6
}

# %%
nodes = []
for i in range(len(df_listFaculty)):
    faculty = df_listFaculty['Title'][i]
    area = df_listFaculty['Area'][i]
    areaNumber = areaNumbers[area]
    
    nodes.append({
        "id": faculty,
        "group": areaNumber
    })
    
nodes
# Out:
# [{'id': 'Amir Yacoby', 'group': 1},
#  {'id': 'Ann Pearson', 'group': 5},
#  {'id': 'Ariel Amir', 'group': 0},
#  {'id': 'Ariel Procaccia', 'group': 3},
#  {'id': 'Barbara J. Grosz', 'group': 3},
#  {'id': 'Boaz Barak', 'group': 3},
#  {'id': 'Boris Kozinsky', 'group': 6},
#  {'id': 'Brian F. Farrell', 'group': 5},
#  {'id': 'Cengiz Pehlevan', 'group': 0},
#  {'id': 'Cherry Murray', 'group': 1},
#  {'id': 'Christin Y. Sander', 'group': 2},
#  {'id': 'Christopher Joseph Lombardo', 'group': 6},
#  {'id': 'Christopher Rycroft', 'group': 0},
#  {'id': 'Conor J Walsh', 'group': 6},
#  {'id': 'Cynthia Dwork', 'group': 3},
#  {'id': 'Cynthia Friend', 'group': 6},
#  {'id': 'Daniel J. Jacob', 'group': 5},
#  {'id': 'Daniel Needleman', 'group': 1},
#  {'id': 'Daniel P. Schrag', 'group': 5},
#  {'id': 'David A. Weitz', 'group': 1},
#  {'id': 'David Brooks', 'group': 3},
#  {'id': 'David C. Bell', 'group': 1},
#  {'id': 'David Clarke', 'group': 6},
#  {'id': 'David J. Malan', 'group': 3},
#  {'id': 'David Keith', 'group': 5},
#  {'id': 'David Mooney', 'group': 2},
#  {'id': 'David Parkes', 'group': 3},
#  {'id': 'David R. Nelson', 'group': 1},
#  {'id': 'Demba Ba', 'group': 4},
#  {'id': 'Doeke Romke Hekstra', 'group': 1},
#  {'id': 'Donald Elliot Ingber', 'group': 2},
#  {'id': 'Donhee Ham', 'group': 1},
#  {'id': 'Eddie Kohler', 'group': 3},
#  {'id': 'Efthimios Kaxiras', 'group': 1},
#  {'id': 'Elena Leah Glassman', 'group': 3},
#  {'id': 'Eli Tziperman', 'group': 5},
#  {'id': 'Elsie M Sunderland', 'group': 5},
#  {'id': 'Eric Mazur', 'group': 1},
#  {'id': 'Evelyn Hu', 'group': 4},
#  {'id': 'Federico Capasso', 'group': 1},
#  {'id': 'Finale Doshi-Velez', 'group': 3},
#  {'id': 'Flavio P. Calmon', 'group': 4},
#  {'id': 'Frank J. Doyle', 'group': 2},
#  {'id': 'Frank N Keutsch', 'group': 5},
#  {'id': 'Frans A. Spaepen', 'group': 6},
#  {'id': 'Gu-Yeon Wei', 'group': 4},
#  {'id': 'H.T. Kung', 'group': 3},
#  {'id': 'Hanspeter Pfister', 'group': 3},
#  {'id': 'Harry R. Lewis', 'group': 3},
#  {'id': 'James G. Anderson', 'group': 5},
#  {'id': 'James H. Waldo', 'group': 3},
#  {'id': 'James Mickens', 'group': 3},
#  {'id': 'James R. Rice', 'group': 6},
#  {'id': 'Jennifer Lewis', 'group': 6},
#  {'id': 'Jenny Hoffman', 'group': 1},
#  {'id': 'Jerry X. Mitrovica', 'group': 5},
#  {'id': 'Jia Liu', 'group': 2},
#  {'id': 'Joanna Aizenberg', 'group': 6},
#  {'id': 'John H. Shaw', 'group': 5},
#  {'id': 'John P. Holdren', 'group': 5},
#  {'id': 'Jonathan Zittrain', 'group': 3},
#  {'id': 'Joost J. Vlassak', 'group': 6},
#  {'id': 'Joze Bevk', 'group': 1},
#  {'id': 'Julia A. Mundy', 'group': 1},
#  {'id': 'Kaighin A McColl', 'group': 5},
#  {'id': 'Karen Brennan', 'group': 3},
#  {'id': 'Katia Bertoldi', 'group': 6},
#  {'id': 'Kit Parker', 'group': 2},
#  {'id': 'Krzysztof Z Gajos', 'group': 3},
#  {'id': 'L Mahadevan', 'group': 0},
#  {'id': 'Lene V. Hau', 'group': 1},
#  {'id': 'Leslie G. Valiant', 'group': 3},
#  {'id': 'Madhu Sudan', 'group': 3},
#  {'id': 'Margo S Levine', 'group': 0},
#  {'id': 'Marianna Katherine Linz', 'group': 5},
#  {'id': 'Marko Loncar', 'group': 1},
#  {'id': 'Markus Thomas Basan', 'group': 1},
#  {'id': 'Maurice Smith', 'group': 2},
#  {'id': 'Maxim Prigozhin', 'group': 1},
#  {'id': 'Michael B. McElroy', 'group': 5},
#  {'id': 'Michael D. Mitzenmacher', 'group': 3},
#  {'id': 'Michael D. Smith', 'group': 3},
#  {'id': 'Michael J. Aziz', 'group': 6},
#  {'id': 'Michael P. Brenner', 'group': 0},
#  {'id': 'Milind Tambe', 'group': 3},
#  {'id': 'Minlan Yu', 'group': 3},
#  {'id': 'Na Li', 'group': 4},
#  {'id': 'Nada Amin', 'group': 3},
#  {'id': 'Noel Michele Holbrook', 'group': 5},
#  {'id': 'Paul R Moorcroft', 'group': 5},
#  {'id': 'Pavlos Protopapas', 'group': 3},
#  {'id': 'Peter John Huybers', 'group': 5},
#  {'id': 'Philip Kim', 'group': 1},
#  {'id': 'Philippe Cluzel', 'group': 1},
#  {'id': 'Prineha Narang', 'group': 6},
#  {'id': 'Radhika Nagpal', 'group': 3},
#  {'id': 'Richard McCullough', 'group': 6},
#  {'id': 'Robert D. Howe', 'group': 6},
#  {'id': 'Robert J. Wood', 'group': 6},
#  {'id': 'Robert M. Westervelt', 'group': 1},
#  {'id': 'Robin Wordsworth', 'group': 5},
#  {'id': 'Roy G. Gordon', 'group': 6},
#  {'id': 'Salil P. Vadhan', 'group': 3},
#  {'id': 'Samir Mitragotri', 'group': 2},
#  {'id': 'Scot T. Martin', 'group': 5},
#  {'id': 'Sharad Ramanathan', 'group': 1},
#  {'id': 'Stephanie Gil', 'group': 3},
#  {'id': 'Stephen Chong', 'group': 3},
#  {'id': 'Steven C. Wofsy', 'group': 5},
#  {'id': 'Steven J. Gortler', 'group': 3},
#  {'id': 'Stratos Idreos', 'group': 3},
#  {'id': 'Stuart M. Shieber', 'group': 3},
#  {'id': 'Susan A Murphy', 'group': 3},
#  {'id': 'Tai T. Wu', 'group': 1},
#  {'id': 'Todd Zickler', 'group': 4},
#  {'id': 'Venkatesh Narayanamurti', 'group': 1},
#  {'id': 'Vijay Janapa Reddi', 'group': 4},
#  {'id': 'Vinothan N. Manoharan', 'group': 1},
#  {'id': 'Woodward Yang', 'group': 4},
#  {'id': 'Xin Li', 'group': 6},
#  {'id': 'Yaron Singer', 'group': 3},
#  {'id': 'Yiling Chen', 'group': 3},
#  {'id': 'Yue Lu', 'group': 4},
#  {'id': 'Zhigang Suo', 'group': 6},
#  {'id': 'Zhiming Kuang', 'group': 5}]

# %% [markdown]
# # Export nodes and links as JSON

# %%
collabJson = {
    "nodes": nodes,
    "links": links
}

collabJson
# Out:
# {'nodes': [{'id': 'Amir Yacoby', 'group': 1},
#   {'id': 'Ann Pearson', 'group': 5},
#   {'id': 'Ariel Amir', 'group': 0},
#   {'id': 'Ariel Procaccia', 'group': 3},
#   {'id': 'Barbara J. Grosz', 'group': 3},
#   {'id': 'Boaz Barak', 'group': 3},
#   {'id': 'Boris Kozinsky', 'group': 6},
#   {'id': 'Brian F. Farrell', 'group': 5},
#   {'id': 'Cengiz Pehlevan', 'group': 0},
#   {'id': 'Cherry Murray', 'group': 1},
#   {'id': 'Christin Y. Sander', 'group': 2},
#   {'id': 'Christopher Joseph Lombardo', 'group': 6},
#   {'id': 'Christopher Rycroft', 'group': 0},
#   {'id': 'Conor J Walsh', 'group': 6},
#   {'id': 'Cynthia Dwork', 'group': 3},
#   {'id': 'Cynthia Friend', 'group': 6},
#   {'id': 'Daniel J. Jacob', 'group': 5},
#   {'id': 'Daniel Needleman', 'group': 1},
#   {'id': 'Daniel P. Schrag', 'group': 5},
#   {'id': 'David A. Weitz', 'group': 1},
#   {'id': 'David Brooks', 'group': 3},
#   {'id': 'David C. Bell', 'group': 1},
#   {'id': 'David Clarke', 'group': 6},
#   {'id': 'David J. Malan', 'group': 3},
#   {'id': 'David Keith', 'group': 5},
#   {'id': 'David Mooney', 'group': 2},
#   {'id': 'David Parkes', 'group': 3},
#   {'id': 'David R. Nelson', 'group': 1},
#   {'id': 'Demba Ba', 'group': 4},
#   {'id': 'Doeke Romke Hekstra', 'group': 1},
#   {'id': 'Donald Elliot Ingber', 'group': 2},
#   {'id': 'Donhee Ham', 'group': 1},
#   {'id': 'Eddie Kohler', 'group': 3},
#   {'id': 'Efthimios Kaxiras', 'group': 1},
#   {'id': 'Elena Leah Glassman', 'group': 3},
#   {'id': 'Eli Tziperman', 'group': 5},
#   {'id': 'Elsie M Sunderland', 'group': 5},
#   {'id': 'Eric Mazur', 'group': 1},
#   {'id': 'Evelyn Hu', 'group': 4},
#   {'id': 'Federico Capasso', 'group': 1},
#   {'id': 'Finale Doshi-Velez', 'group': 3},
#   {'id': 'Flavio P. Calmon', 'group': 4},
#   {'id': 'Frank J. Doyle', 'group': 2},
#   {'id': 'Frank N Keutsch', 'group': 5},
#   {'id': 'Frans A. Spaepen', 'group': 6},
#   {'id': 'Gu-Yeon Wei', 'group': 4},
#   {'id': 'H.T. Kung', 'group': 3},
#   {'id': 'Hanspeter Pfister', 'group': 3},
#   {'id': 'Harry R. Lewis', 'group': 3},
#   {'id': 'James G. Anderson', 'group': 5},
#   {'id': 'James H. Waldo', 'group': 3},
#   {'id': 'James Mickens', 'group': 3},
#   {'id': 'James R. Rice', 'group': 6},
#   {'id': 'Jennifer Lewis', 'group': 6},
#   {'id': 'Jenny Hoffman', 'group': 1},
#   {'id': 'Jerry X. Mitrovica', 'group': 5},
#   {'id': 'Jia Liu', 'group': 2},
#   {'id': 'Joanna Aizenberg', 'group': 6},
#   {'id': 'John H. Shaw', 'group': 5},
#   {'id': 'John P. Holdren', 'group': 5},
#   {'id': 'Jonathan Zittrain', 'group': 3},
#   {'id': 'Joost J. Vlassak', 'group': 6},
#   {'id': 'Joze Bevk', 'group': 1},
#   {'id': 'Julia A. Mundy', 'group': 1},
#   {'id': 'Kaighin A McColl', 'group': 5},
#   {'id': 'Karen Brennan', 'group': 3},
#   {'id': 'Katia Bertoldi', 'group': 6},
#   {'id': 'Kit Parker', 'group': 2},
#   {'id': 'Krzysztof Z Gajos', 'group': 3},
#   {'id': 'L Mahadevan', 'group': 0},
#   {'id': 'Lene V. Hau', 'group': 1},
#   {'id': 'Leslie G. Valiant', 'group': 3},
#   {'id': 'Madhu Sudan', 'group': 3},
#   {'id': 'Margo S Levine', 'group': 0},
#   {'id': 'Marianna Katherine Linz', 'group': 5},
#   {'id': 'Marko Loncar', 'group': 1},
#   {'id': 'Markus Thomas Basan', 'group': 1},
#   {'id': 'Maurice Smith', 'group': 2},
#   {'id': 'Maxim Prigozhin', 'group': 1},
#   {'id': 'Michael B. McElroy', 'group': 5},
#   {'id': 'Michael D. Mitzenmacher', 'group': 3},
#   {'id': 'Michael D. Smith', 'group': 3},
#   {'id': 'Michael J. Aziz', 'group': 6},
#   {'id': 'Michael P. Brenner', 'group': 0},
#   {'id': 'Milind Tambe', 'group': 3},
#   {'id': 'Minlan Yu', 'group': 3},
#   {'id': 'Na Li', 'group': 4},
#   {'id': 'Nada Amin', 'group': 3},
#   {'id': 'Noel Michele Holbrook', 'group': 5},
#   {'id': 'Paul R Moorcroft', 'group': 5},
#   {'id': 'Pavlos Protopapas', 'group': 3},
#   {'id': 'Peter John Huybers', 'group': 5},
#   {'id': 'Philip Kim', 'group': 1},
#   {'id': 'Philippe Cluzel', 'group': 1},
#   {'id': 'Prineha Narang', 'group': 6},
#   {'id': 'Radhika Nagpal', 'group': 3},
#   {'id': 'Richard McCullough', 'group': 6},
#   {'id': 'Robert D. Howe', 'group': 6},
#   {'id': 'Robert J. Wood', 'group': 6},
#   {'id': 'Robert M. Westervelt', 'group': 1},
#   {'id': 'Robin Wordsworth', 'group': 5},
#   {'id': 'Roy G. Gordon', 'group': 6},
#   {'id': 'Salil P. Vadhan', 'group': 3},
#   {'id': 'Samir Mitragotri', 'group': 2},
#   {'id': 'Scot T. Martin', 'group': 5},
#   {'id': 'Sharad Ramanathan', 'group': 1},
#   {'id': 'Stephanie Gil', 'group': 3},
#   {'id': 'Stephen Chong', 'group': 3},
#   {'id': 'Steven C. Wofsy', 'group': 5},
#   {'id': 'Steven J. Gortler', 'group': 3},
#   {'id': 'Stratos Idreos', 'group': 3},
#   {'id': 'Stuart M. Shieber', 'group': 3},
#   {'id': 'Susan A Murphy', 'group': 3},
#   {'id': 'Tai T. Wu', 'group': 1},
#   {'id': 'Todd Zickler', 'group': 4},
#   {'id': 'Venkatesh Narayanamurti', 'group': 1},
#   {'id': 'Vijay Janapa Reddi', 'group': 4},
#   {'id': 'Vinothan N. Manoharan', 'group': 1},
#   {'id': 'Woodward Yang', 'group': 4},
#   {'id': 'Xin Li', 'group': 6},
#   {'id': 'Yaron Singer', 'group': 3},
#   {'id': 'Yiling Chen', 'group': 3},
#   {'id': 'Yue Lu', 'group': 4},
#   {'id': 'Zhigang Suo', 'group': 6},
#   {'id': 'Zhiming Kuang', 'group': 5}],
#  'links': [{'source': 'David Brooks', 'target': 'Gu-Yeon Wei', 'value': 153},
#   {'source': 'Daniel J. Jacob', 'target': 'Steven C. Wofsy', 'value': 60},
#   {'source': 'Federico Capasso', 'target': 'Marko Loncar', 'value': 55},
#   {'source': 'Conor J Walsh', 'target': 'Robert J. Wood', 'value': 50},
#   {'source': 'Joost J. Vlassak', 'target': 'Zhigang Suo', 'value': 46},
#   {'source': 'Cynthia Friend', 'target': 'Efthimios Kaxiras', 'value': 44},
#   {'source': 'Eric Mazur', 'target': 'Marko Loncar', 'value': 30},
#   {'source': 'Daniel J. Jacob', 'target': 'Elsie M Sunderland', 'value': 28},
#   {'source': 'David Brooks', 'target': 'Vijay Janapa Reddi', 'value': 24},
#   {'source': 'Donald Elliot Ingber', 'target': 'Kit Parker', 'value': 23},
#   {'source': 'Jerry X. Mitrovica',
#    'target': 'Peter John Huybers',
#    'value': 23},
#   {'source': 'Gu-Yeon Wei', 'target': 'Vijay Janapa Reddi', 'value': 21},
#   {'source': 'Amir Yacoby', 'target': 'Philip Kim', 'value': 19},
#   {'source': 'Radhika Nagpal', 'target': 'Robert J. Wood', 'value': 19},
#   {'source': 'David Mooney', 'target': 'Donald Elliot Ingber', 'value': 19},
#   {'source': 'Conor J Walsh', 'target': 'David Mooney', 'value': 18},
#   {'source': 'Joanna Aizenberg', 'target': 'Marko Loncar', 'value': 16},
#   {'source': 'Gu-Yeon Wei', 'target': 'Robert J. Wood', 'value': 14},
#   {'source': 'David Clarke', 'target': 'Robert J. Wood', 'value': 14},
#   {'source': 'Joanna Aizenberg', 'target': 'Katia Bertoldi', 'value': 14},
#   {'source': 'Steven J. Gortler', 'target': 'Todd Zickler', 'value': 14},
#   {'source': 'Amir Yacoby', 'target': 'Marko Loncar', 'value': 13},
#   {'source': 'Conor J Walsh', 'target': 'Katia Bertoldi', 'value': 13},
#   {'source': 'Cynthia Friend', 'target': 'Joanna Aizenberg', 'value': 13},
#   {'source': 'David A. Weitz', 'target': 'L Mahadevan', 'value': 13},
#   {'source': 'David Clarke', 'target': 'Zhigang Suo', 'value': 13},
#   {'source': 'Eric Mazur', 'target': 'Michael J. Aziz', 'value': 13},
#   {'source': 'David A. Weitz', 'target': 'David Mooney', 'value': 12},
#   {'source': 'David Clarke', 'target': 'Katia Bertoldi', 'value': 12},
#   {'source': 'Federico Capasso', 'target': 'Philip Kim', 'value': 12},
#   {'source': 'Efthimios Kaxiras', 'target': 'Philip Kim', 'value': 11},
#   {'source': 'David Brooks', 'target': 'Michael D. Smith', 'value': 10},
#   {'source': 'Gu-Yeon Wei', 'target': 'Michael D. Smith', 'value': 10},
#   {'source': 'Michael D. Smith', 'target': 'Vijay Janapa Reddi', 'value': 10},
#   {'source': 'Philip Kim', 'target': 'Robert M. Westervelt', 'value': 10},
#   {'source': 'Hanspeter Pfister', 'target': 'Krzysztof Z Gajos', 'value': 10},
#   {'source': 'Madhu Sudan', 'target': 'Salil P. Vadhan', 'value': 10},
#   {'source': 'David Parkes', 'target': 'Yiling Chen', 'value': 9},
#   {'source': 'Daniel P. Schrag', 'target': 'Michael J. Aziz', 'value': 9},
#   {'source': 'Federico Capasso',
#    'target': 'Venkatesh Narayanamurti',
#    'value': 9},
#   {'source': 'Daniel P. Schrag', 'target': 'Eli Tziperman', 'value': 8},
#   {'source': 'Donald Elliot Ingber', 'target': 'Eric Mazur', 'value': 8},
#   {'source': 'Donald Elliot Ingber', 'target': 'Joanna Aizenberg', 'value': 8},
#   {'source': 'Efthimios Kaxiras', 'target': 'Joost J. Vlassak', 'value': 8},
#   {'source': 'Joanna Aizenberg', 'target': 'L Mahadevan', 'value': 8},
#   {'source': 'Ariel Procaccia', 'target': 'David Parkes', 'value': 7},
#   {'source': 'David A. Weitz', 'target': 'Donald Elliot Ingber', 'value': 7},
#   {'source': 'David Mooney', 'target': 'Zhigang Suo', 'value': 7},
#   {'source': 'Efthimios Kaxiras',
#    'target': 'Robert M. Westervelt',
#    'value': 7},
#   {'source': 'Michael J. Aziz',
#    'target': 'Venkatesh Narayanamurti',
#    'value': 7},
#   {'source': 'Amir Yacoby', 'target': 'Efthimios Kaxiras', 'value': 6},
#   {'source': 'Cynthia Friend', 'target': 'Eric Mazur', 'value': 6},
#   {'source': 'David A. Weitz', 'target': 'David R. Nelson', 'value': 6},
#   {'source': 'Federico Capasso', 'target': 'Michael J. Aziz', 'value': 6},
#   {'source': 'Ariel Procaccia', 'target': 'Yiling Chen', 'value': 5},
#   {'source': 'Daniel J. Jacob', 'target': 'Scot T. Martin', 'value': 5},
#   {'source': 'Kit Parker', 'target': 'L Mahadevan', 'value': 5},
#   {'source': 'David Brooks', 'target': 'Robert J. Wood', 'value': 5},
#   {'source': 'David Clarke', 'target': 'Federico Capasso', 'value': 5},
#   {'source': 'Katia Bertoldi', 'target': 'Zhigang Suo', 'value': 5},
#   {'source': 'Efthimios Kaxiras', 'target': 'Michael J. Aziz', 'value': 5},
#   {'source': 'Federico Capasso',
#    'target': 'Vinothan N. Manoharan',
#    'value': 5},
#   {'source': 'Federico Capasso', 'target': 'Joanna Aizenberg', 'value': 5},
#   {'source': 'Joanna Aizenberg', 'target': 'Zhigang Suo', 'value': 5},
#   {'source': 'David Parkes', 'target': 'Krzysztof Z Gajos', 'value': 4},
#   {'source': 'Ariel Procaccia', 'target': 'Milind Tambe', 'value': 4},
#   {'source': 'Katia Bertoldi', 'target': 'Robert J. Wood', 'value': 4},
#   {'source': 'Daniel P. Schrag', 'target': 'David Keith', 'value': 4},
#   {'source': 'David A. Weitz', 'target': 'Kit Parker', 'value': 4},
#   {'source': 'David A. Weitz', 'target': 'Vinothan N. Manoharan', 'value': 4},
#   {'source': 'David Mooney', 'target': 'Joost J. Vlassak', 'value': 4},
#   {'source': 'Efthimios Kaxiras', 'target': 'Zhigang Suo', 'value': 4},
#   {'source': 'Efthimios Kaxiras', 'target': 'Hanspeter Pfister', 'value': 4},
#   {'source': 'Eric Mazur', 'target': 'Salil P. Vadhan', 'value': 4},
#   {'source': 'Jennifer Lewis', 'target': 'Robert J. Wood', 'value': 4},
#   {'source': 'Jennifer Lewis', 'target': 'Katia Bertoldi', 'value': 4},
#   {'source': 'Amir Yacoby', 'target': 'Prineha Narang', 'value': 3},
#   {'source': 'Boaz Barak', 'target': 'Salil P. Vadhan', 'value': 3},
#   {'source': 'Jia Liu', 'target': 'Zhigang Suo', 'value': 3},
#   {'source': 'Christopher Rycroft', 'target': 'L Mahadevan', 'value': 3},
#   {'source': 'Cynthia Friend', 'target': 'Scot T. Martin', 'value': 3},
#   {'source': 'David A. Weitz', 'target': 'Robert M. Westervelt', 'value': 3},
#   {'source': 'David Brooks', 'target': 'Michael D. Mitzenmacher', 'value': 3},
#   {'source': 'Gu-Yeon Wei', 'target': 'Michael D. Mitzenmacher', 'value': 3},
#   {'source': 'David Clarke', 'target': 'Jennifer Lewis', 'value': 3},
#   {'source': 'David Clarke', 'target': 'Radhika Nagpal', 'value': 3},
#   {'source': 'David Parkes', 'target': 'Michael D. Mitzenmacher', 'value': 3},
#   {'source': 'Donald Elliot Ingber',
#    'target': 'Robert M. Westervelt',
#    'value': 3},
#   {'source': 'Donald Elliot Ingber', 'target': 'Radhika Nagpal', 'value': 3},
#   {'source': 'Federico Capasso', 'target': 'Todd Zickler', 'value': 3},
#   {'source': 'Finale Doshi-Velez', 'target': 'Susan A Murphy', 'value': 3},
#   {'source': 'Jennifer Lewis', 'target': 'Joanna Aizenberg', 'value': 3},
#   {'source': 'Joost J. Vlassak', 'target': 'Kit Parker', 'value': 3},
#   {'source': 'Krzysztof Z Gajos', 'target': 'Stuart M. Shieber', 'value': 3},
#   {'source': 'Marko Loncar', 'target': 'Robert M. Westervelt', 'value': 3},
#   {'source': 'Michael D. Mitzenmacher',
#    'target': 'Salil P. Vadhan',
#    'value': 3},
#   {'source': 'Ann Pearson', 'target': 'Daniel P. Schrag', 'value': 2},
#   {'source': 'Ann Pearson', 'target': 'Peter John Huybers', 'value': 2},
#   {'source': 'Boris Kozinsky', 'target': 'Cynthia Friend', 'value': 2},
#   {'source': 'Conor J Walsh', 'target': 'Jennifer Lewis', 'value': 2},
#   {'source': 'David Mooney', 'target': 'Katia Bertoldi', 'value': 2},
#   {'source': 'Conor J Walsh', 'target': 'Radhika Nagpal', 'value': 2},
#   {'source': 'Joost J. Vlassak', 'target': 'Robert J. Wood', 'value': 2},
#   {'source': 'Daniel J. Jacob', 'target': 'Daniel P. Schrag', 'value': 2},
#   {'source': 'Eli Tziperman', 'target': 'Steven C. Wofsy', 'value': 2},
#   {'source': 'Daniel P. Schrag', 'target': 'Jerry X. Mitrovica', 'value': 2},
#   {'source': 'Donald Elliot Ingber', 'target': 'L Mahadevan', 'value': 2},
#   {'source': 'David A. Weitz', 'target': 'Joanna Aizenberg', 'value': 2},
#   {'source': 'David A. Weitz', 'target': 'Zhigang Suo', 'value': 2},
#   {'source': 'David A. Weitz', 'target': 'Michael J. Aziz', 'value': 2},
#   {'source': 'David Mooney', 'target': 'Eric Mazur', 'value': 2},
#   {'source': 'David Parkes', 'target': 'Milind Tambe', 'value': 2},
#   {'source': 'David R. Nelson', 'target': 'Joanna Aizenberg', 'value': 2},
#   {'source': 'Efthimios Kaxiras', 'target': 'Jenny Hoffman', 'value': 2},
#   {'source': 'Efthimios Kaxiras', 'target': 'Pavlos Protopapas', 'value': 2},
#   {'source': 'Eli Tziperman', 'target': 'Peter John Huybers', 'value': 2},
#   {'source': 'Eli Tziperman', 'target': 'Marianna Katherine Linz', 'value': 2},
#   {'source': 'Marko Loncar', 'target': 'Michael J. Aziz', 'value': 2},
#   {'source': 'Finale Doshi-Velez', 'target': 'Krzysztof Z Gajos', 'value': 2},
#   {'source': 'Finale Doshi-Velez', 'target': 'Milind Tambe', 'value': 2},
#   {'source': 'H.T. Kung', 'target': 'Michael D. Smith', 'value': 2},
#   {'source': 'Hanspeter Pfister', 'target': 'Todd Zickler', 'value': 2},
#   {'source': 'Hanspeter Pfister',
#    'target': 'Michael D. Mitzenmacher',
#    'value': 2},
#   {'source': 'Jennifer Lewis', 'target': 'L Mahadevan', 'value': 2},
#   {'source': 'Jennifer Lewis', 'target': 'Joost J. Vlassak', 'value': 2},
#   {'source': 'Joanna Aizenberg', 'target': 'Joost J. Vlassak', 'value': 2},
#   {'source': 'Joost J. Vlassak', 'target': 'Michael J. Aziz', 'value': 2},
#   {'source': 'Kit Parker', 'target': 'Robert J. Wood', 'value': 2},
#   {'source': 'Katia Bertoldi', 'target': 'Kit Parker', 'value': 2},
#   {'source': 'Marko Loncar', 'target': 'Philip Kim', 'value': 2},
#   {'source': 'Michael D. Mitzenmacher', 'target': 'Minlan Yu', 'value': 2},
#   {'source': 'Salil P. Vadhan', 'target': 'Yiling Chen', 'value': 2},
#   {'source': 'Amir Yacoby', 'target': 'Federico Capasso', 'value': 1},
#   {'source': 'Efthimios Kaxiras', 'target': 'Federico Capasso', 'value': 1},
#   {'source': 'Amir Yacoby', 'target': 'Robert M. Westervelt', 'value': 1},
#   {'source': 'Ariel Procaccia', 'target': 'Krzysztof Z Gajos', 'value': 1},
#   {'source': 'Krzysztof Z Gajos', 'target': 'Yiling Chen', 'value': 1},
#   {'source': 'Ariel Procaccia', 'target': 'Finale Doshi-Velez', 'value': 1},
#   {'source': 'Boaz Barak', 'target': 'Michael D. Mitzenmacher', 'value': 1},
#   {'source': 'Boris Kozinsky', 'target': 'Jia Liu', 'value': 1},
#   {'source': 'Boris Kozinsky', 'target': 'Zhigang Suo', 'value': 1},
#   {'source': 'Boris Kozinsky', 'target': 'Efthimios Kaxiras', 'value': 1},
#   {'source': 'Cengiz Pehlevan', 'target': 'L Mahadevan', 'value': 1},
#   {'source': 'Christopher Rycroft', 'target': 'Katia Bertoldi', 'value': 1},
#   {'source': 'Conor J Walsh', 'target': 'David A. Weitz', 'value': 1},
#   {'source': 'Conor J Walsh', 'target': 'Zhigang Suo', 'value': 1},
#   {'source': 'Conor J Walsh', 'target': 'Joost J. Vlassak', 'value': 1},
#   {'source': 'Conor J Walsh', 'target': 'Finale Doshi-Velez', 'value': 1},
#   {'source': 'Finale Doshi-Velez', 'target': 'Robert J. Wood', 'value': 1},
#   {'source': 'Conor J Walsh', 'target': 'Krzysztof Z Gajos', 'value': 1},
#   {'source': 'Robert J. Wood', 'target': 'Todd Zickler', 'value': 1},
#   {'source': 'Conor J Walsh', 'target': 'Maurice Smith', 'value': 1},
#   {'source': 'Cynthia Dwork', 'target': 'Salil P. Vadhan', 'value': 1},
#   {'source': 'Cynthia Friend', 'target': 'Joost J. Vlassak', 'value': 1},
#   {'source': 'Joost J. Vlassak', 'target': 'Scot T. Martin', 'value': 1},
#   {'source': 'Efthimios Kaxiras', 'target': 'Joanna Aizenberg', 'value': 1},
#   {'source': 'Cynthia Friend', 'target': 'Michael J. Aziz', 'value': 1},
#   {'source': 'Daniel J. Jacob', 'target': 'David Keith', 'value': 1},
#   {'source': 'Daniel J. Jacob', 'target': 'Eli Tziperman', 'value': 1},
#   {'source': 'Daniel P. Schrag', 'target': 'Steven C. Wofsy', 'value': 1},
#   {'source': 'David A. Weitz', 'target': 'Jennifer Lewis', 'value': 1},
#   {'source': 'David A. Weitz', 'target': 'Jerry X. Mitrovica', 'value': 1},
#   {'source': 'David A. Weitz', 'target': 'Katia Bertoldi', 'value': 1},
#   {'source': 'David A. Weitz', 'target': 'Steven C. Wofsy', 'value': 1},
#   {'source': 'David A. Weitz', 'target': 'Federico Capasso', 'value': 1},
#   {'source': 'Michael D. Mitzenmacher',
#    'target': 'Vijay Janapa Reddi',
#    'value': 1},
#   {'source': 'David Clarke', 'target': 'Kit Parker', 'value': 1},
#   {'source': 'Kit Parker', 'target': 'Zhigang Suo', 'value': 1},
#   {'source': 'David Mooney', 'target': 'Michael P. Brenner', 'value': 1},
#   {'source': 'David Mooney', 'target': 'Joanna Aizenberg', 'value': 1},
#   {'source': 'David Mooney', 'target': 'L Mahadevan', 'value': 1},
#   {'source': 'David Mooney', 'target': 'Samir Mitragotri', 'value': 1},
#   {'source': 'David Parkes', 'target': 'Stuart M. Shieber', 'value': 1},
#   {'source': 'David Parkes', 'target': 'Salil P. Vadhan', 'value': 1},
#   {'source': 'David Parkes', 'target': 'Yaron Singer', 'value': 1},
#   {'source': 'David Parkes', 'target': 'Finale Doshi-Velez', 'value': 1},
#   {'source': 'Philip Kim', 'target': 'Radhika Nagpal', 'value': 1},
#   {'source': 'David R. Nelson', 'target': 'Vinothan N. Manoharan', 'value': 1},
#   {'source': 'David R. Nelson', 'target': 'Joost J. Vlassak', 'value': 1},
#   {'source': 'Demba Ba', 'target': 'Donald Elliot Ingber', 'value': 1},
#   {'source': 'Demba Ba', 'target': 'Steven C. Wofsy', 'value': 1},
#   {'source': 'Donald Elliot Ingber', 'target': 'Steven C. Wofsy', 'value': 1},
#   {'source': 'Donald Elliot Ingber', 'target': 'Katia Bertoldi', 'value': 1},
#   {'source': 'Donald Elliot Ingber', 'target': 'Samir Mitragotri', 'value': 1},
#   {'source': 'Eddie Kohler', 'target': 'James Mickens', 'value': 1},
#   {'source': 'Efthimios Kaxiras', 'target': 'Prineha Narang', 'value': 1},
#   {'source': 'Efthimios Kaxiras', 'target': 'Eric Mazur', 'value': 1},
#   {'source': 'Elena Leah Glassman', 'target': 'Stephen Chong', 'value': 1},
#   {'source': 'Elena Leah Glassman',
#    'target': 'Finale Doshi-Velez',
#    'value': 1},
#   {'source': 'Elsie M Sunderland', 'target': 'Steven C. Wofsy', 'value': 1},
#   {'source': 'Eric Mazur', 'target': 'Joanna Aizenberg', 'value': 1},
#   {'source': 'Eric Mazur', 'target': 'Todd Zickler', 'value': 1},
#   {'source': 'Federico Capasso', 'target': 'Jennifer Lewis', 'value': 1},
#   {'source': 'Federico Capasso', 'target': 'Kit Parker', 'value': 1},
#   {'source': 'Finale Doshi-Velez', 'target': 'James H. Waldo', 'value': 1},
#   {'source': 'Finale Doshi-Velez', 'target': 'Pavlos Protopapas', 'value': 1},
#   {'source': 'Gu-Yeon Wei', 'target': 'Radhika Nagpal', 'value': 1},
#   {'source': 'H.T. Kung', 'target': 'Radhika Nagpal', 'value': 1},
#   {'source': 'H.T. Kung', 'target': 'Robert J. Wood', 'value': 1},
#   {'source': 'H.T. Kung', 'target': 'Stuart M. Shieber', 'value': 1},
#   {'source': 'Michael D. Smith', 'target': 'Stuart M. Shieber', 'value': 1},
#   {'source': 'Hanspeter Pfister', 'target': 'Stuart M. Shieber', 'value': 1},
#   {'source': 'Hanspeter Pfister', 'target': 'Radhika Nagpal', 'value': 1},
#   {'source': 'Krzysztof Z Gajos', 'target': 'Radhika Nagpal', 'value': 1},
#   {'source': 'James Mickens', 'target': 'Stephanie Gil', 'value': 1},
#   {'source': 'James R. Rice', 'target': 'Zhigang Suo', 'value': 1},
#   {'source': 'Jennifer Lewis', 'target': 'Kit Parker', 'value': 1},
#   {'source': 'Jennifer Lewis', 'target': 'Michael J. Aziz', 'value': 1},
#   {'source': 'Joanna Aizenberg', 'target': 'Michael J. Aziz', 'value': 1},
#   {'source': 'Joanna Aizenberg',
#    'target': 'Vinothan N. Manoharan',
#    'value': 1},
#   {'source': 'Joost J. Vlassak', 'target': 'L Mahadevan', 'value': 1},
#   {'source': 'Kaighin A McColl', 'target': 'Peter John Huybers', 'value': 1},
#   {'source': 'L Mahadevan', 'target': 'Robert J. Wood', 'value': 1},
#   {'source': 'L Mahadevan', 'target': 'Vinothan N. Manoharan', 'value': 1},
#   {'source': 'Madhu Sudan', 'target': 'Michael D. Mitzenmacher', 'value': 1},
#   {'source': 'Marianna Katherine Linz',
#    'target': 'Steven C. Wofsy',
#    'value': 1},
#   {'source': 'Marko Loncar', 'target': 'Prineha Narang', 'value': 1},
#   {'source': 'Marko Loncar', 'target': 'Venkatesh Narayanamurti', 'value': 1},
#   {'source': 'Michael D. Mitzenmacher', 'target': 'Milind Tambe', 'value': 1},
#   {'source': 'Michael D. Mitzenmacher', 'target': 'Yaron Singer', 'value': 1},
#   {'source': 'Milind Tambe', 'target': 'Yaron Singer', 'value': 1},
#   {'source': 'Milind Tambe', 'target': 'Minlan Yu', 'value': 1},
#   {'source': 'Peter John Huybers', 'target': 'Steven C. Wofsy', 'value': 1},
#   {'source': 'Salil P. Vadhan', 'target': 'Stephen Chong', 'value': 1},
#   {'source': 'Stephen Chong', 'target': 'Yiling Chen', 'value': 1}]}

# %%
with open('faculty_collabs.json', 'w') as f:
    json.dump(collabJson, f, ensure_ascii=False, indent=4)
